# %% [markdown]
# # Практическое задание 2
#
# # Распознавание именованных сущностей из Twitter с помощью LSTM
#
# ## курс "Математические методы анализа текстов"
#
#
# ### ФИО: Волынцев Дмитрий Александрович

# %% [markdown]
# ## Введение
#
# ### Постановка задачи
#
# В этом задании вы будете использовать рекуррентные нейронные сети для решения проблемы распознавания именованных сущностей (NER). Примерами именованных сущностей являются имена людей, названия организаций, адреса и т.д. В этом задании вы будете работать с данными twitter.
#
# Например, вы хотите извлечь имена и названия организаций. Тогда для текста
#
#     Yan Goodfellow works for Google Brain
#
# модель должна извлечь следующую последовательность:
#
#     B-PER I-PER    O     O   B-ORG  I-ORG
#
# где префиксы *B-* и *I-* означают начало и конец именованной сущности, *O* означает слово без тега. Такая префиксная система введена, чтобы различать последовательные именованные сущности одного типа.
#
# Решение этого задания будет основано на нейронных сетях, а именно на Bi-Directional Long Short-Term Memory Networks (BiLSTMs). В базовой части задания вам также нужно будет улучшить модель при помощи необучаемого пост-процессинга, основанного на алгоритме Витерби и графической модели CRF. В бонусной части вам будем предложено полноценно использовать связку BiLSTM и CRF, обучая обе модели одновременно.
#
# ### Библиотеки
#
# Для этого задания вам понадобятся следующие библиотеки:
#  - [Pytorch](https://pytorch.org/).
#  - [Numpy](http://www.numpy.org).
#
# ### Данные
#
# Все данные содержатся в папке `./data`: `./data/train.txt`, `./data/validation.txt`, `./data/test.txt`.
#
# Скачать архив можно здесь: [ссылка на google диск](https://drive.google.com/open?id=1s1rFOFMZTBqtJuQDcIvW-8djA78iUDcx)

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## Часть 1. Подготовка данных (2 балла)
#
# ### Загрузка данных
#
# Мы будем работать с данными, которые содержат твиты с тегами именованных сущностей. Каждая строка файла содержит пару токен (слово или пунктуация) и тег, разделенные пробелом. Различные твиты разделены пустой строкой.
#
# Функция *read_data* считывает корпус из *file_path* и возвращает два списка: один с токенами и один с соответствующими токенам тегами. Также она заменяет все ники (токены, которые начинаются на символ *@*) на токен `<USR>` и url-ы (токены, которые начинаются на *http://* или *https://*) на токен `<URL>`.
#
# **<font color='red'>Задание. Реализуйте функцию read_data.</font>**

# %%
import re

# %%
def read_data(file_path):
    tokens = []
    tags = []

    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    
    file = open(file_path, "r", encoding = "utf-8")
    
    tokens_list = []
    tags_list = []
    
    for line in file:
        stripped_line = line.strip()
        splitted_line = stripped_line.split(' ')
        
        if len(line.split()) > 0:
            token, tag = splitted_line
            if re.match('http://', token):
                token = '<URL>'
            if re.match('https://', token):
                token = '<URL>'
            if re.match('@', token):
                token = '<USR>'
            
            tokens.append(token)
            tags.append(tag)
            
        #в конце складываем массивы в общий массив и обнуляем их для следующей строки
        else:
            tokens_list.append(tokens)
            tags_list.append(tags)
            tokens = []
            tags = []
    return tokens_list, tags_list

# %% [markdown]
# Теперь мы можем загрузить 3 части данных:
#  - *train* для тренировки модели;
#  - *validation* для валидации и подбора гиперпараметров;
#  - *test* для финального тестирования.

# %%
train_sentences, train_tags = read_data('train.txt')
val_sentences, val_tags = read_data('validation.txt')
test_sentences, test_tags = read_data('test.txt')

# %%
train_sentences
# Out:
# [['RT',
#   '<USR>',
#   ':',
#   'Online',
#   'ticket',
#   'sales',
#   'for',
#   'Ghostland',
#   'Observatory',
#   'extended',
#   'until',
#   '6',
#   'PM',
#   'EST',
#   'due',
#   'to',
#   'high',
#   'demand',
#   '.',
#   'Get',
#   'them',
#   'before',
#   'they',
#   'sell',
#   'out',
#   '...'],
#  ['Apple',
#   'MacBook',
#   'Pro',
#   'A1278',
#   '13.3',
#   '"',
#   'Laptop',
#   '-',
#   'MD101LL/A',
#   '(',
#   'June',
#   ',',
#   '2012',
#   ')',
#   '-',
#   'Full',
#   'read',
#   'by',
#   'eBay',
#   '<URL>',
#   '<URL>'],
#  ['Happy',
#   'Birthday',
#   '<USR>',
#   '!',
#   'May',
#   'Allah',
#   's.w.t',
#   'bless',
#   'you',
#   'with',
#   'goodness',
#   'and',
#   'happiness',
#   '.'],
#  ['<USR>',
#   'the',
#   'quest',
#   'line',
#   'im',
#   'assuming',
#   'it',
#   'will',
#   'be',
#   'the',
#   'same',
#   'way',
#   'with',
#   'awe',
#   'thur'],
#  ['<USR>',
#   '<USR>',
#   '<USR>',
#   '<USR>',
#   '<USR>',
#   'still',
#   'perception',
#   ',',
#   'and',
#   'what',
#   'you',
#   'key',
#   'off',
#   'may',
#   'differ',
#   'from',
#   'me',
#   '.',
#   'Back',
#   'to',
#   'Selma',
#   'example',
#   ',',
#   'iow',
#   '.'],
#  ['Amazon',
#   'Kindle',
#   'Fire',
#   '1st',
#   'Generation',
#   '8GB',
#   ',',
#   'Wi-Fi',
#   ',',
#   '7in',
#   '-',
#   'Black',
#   '-',
#   'Full',
#   'read',
#   'by',
#   'eBay',
#   '<URL>',
#   '<URL>'],
#  ['<USR>', "I'll", 'call', 'u', 'after', 'class', 'pooky', ';D'],
#  ['TL_jp', 'August', '29', ',', '2015', 'at', '01:25', 'AM', '<URL>'],
#  ['<USR>',
#   'Wie',
#   'staat',
#   'daar',
#   'nou',
#   'met',
#   'de',
#   'microfoon',
#   'links',
#   ';-)',
#   '<URL>'],
#  ['Why', 'do', 'I', 'have', 'an', 'exam', 'tomorrow', 'morning', '?'],
#  ['Big',
#   'Day',
#   'tomorrow',
#   '-',
#   'Thanks',
#   'to',
#   'all',
#   'of',
#   'Team',
#   'Pioneers',
#   'who',
#   'have',
#   'been',
#   'busy',
#   'unwrapping',
#   'tables',
#   'and',
#   'unpacking',
#   'boxes',
#   'to',
#   'ensure',
#   'school',
#   'is',
#   'ready',
#   '!'],
#  ['<USR>',
#   'Ive',
#   'heard',
#   'of',
#   'that',
#   '.',
#   "Hadn't",
#   'heard',
#   'it',
#   'called',
#   'that',
#   'before',
#   '.',
#   'I',
#   'considered',
#   'it',
#   'but',
#   'my',
#   'hair',
#   'is',
#   'so',
#   'oily',
#   ',',
#   'I',
#   'think',
#   'I',
#   'would',
#   'look',
#   'dirty',
#   '.',
#   ':)'],
#  ['Life',
#   'may',
#   'feel',
#   'somewhat',
#   'unstable',
#   'today',
#   'as',
#   'your',
#   'self-esteem',
#   'soar',
#   '...',
#   'More',
#   'for',
#   'Aquarius',
#   '<URL>'],
#  ['#BREAKING',
#   ':',
#   'NEW',
#   ':',
#   '1',
#   'dead',
#   ',',
#   'as',
#   'many',
#   'as',
#   '15',
#   'injured',
#   'in',
#   'Fort',
#   'Hood',
#   'shooting',
#   '.',
#   'SWAT',
#   ',',
#   '21',
#   'ambulances',
#   'now',
#   'on',
#   'scene',
#   '.',
#   '-',
#   'KWTX',
#   '-',
#   'CBS-TV',
#   '#FortHood'],
#  ['#4GElite2',
#   'A',
#   'Premium',
#   'Budget',
#   'Phone',
#   '!',
#   'Promising',
#   'Future',
#   'Updates',
#   '!',
#   'ELITE',
#   '2',
#   'is',
#   'Better',
#   'than',
#   'Anything',
#   'Before',
#   '!',
#   'Launch',
#   'on',
#   '8',
#   'Nov',
#   'On',
#   '<USR>',
#   '<USR>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'PSA',
#   ':',
#   'roll',
#   'up',
#   'the',
#   'rim',
#   'starts',
#   'Monday',
#   '!!'],
#  ['The',
#   'bank',
#   'teller',
#   'I',
#   'always',
#   'go',
#   'to',
#   'wants',
#   'me',
#   '.',
#   'Lol',
#   '.',
#   'No',
#   'shit',
#   '.',
#   'She',
#   'left',
#   'me',
#   'wide',
#   'open',
#   'for',
#   'tomorrow',
#   '.',
#   'Too',
#   'bad',
#   'I',
#   'already',
#   'have',
#   'fucking',
#   'plans',
#   '!'],
#  ['RT',
#   '<USR>',
#   '#LASD',
#   'Arson/Explosives',
#   'Detail',
#   '(',
#   'Bomb',
#   'Squad',
#   ')',
#   'on',
#   'scene',
#   'assisting',
#   'at',
#   'Santa',
#   'Monica',
#   'College',
#   're',
#   ':',
#   'shooting',
#   'incident',
#   '<USR>'],
#  ['the',
#   'group',
#   'Maunalua',
#   'will',
#   'be',
#   'playing',
#   'tomorrow',
#   '<USR>',
#   'at',
#   'Noon',
#   '!'],
#  ['#Retweet',
#   '#siguemeytesigo',
#   '#autofollowback',
#   '#teamfollowback',
#   '#MGWV',
#   '#tfbjp',
#   '#f4f',
#   '#followtrain',
#   '#followtrick',
#   'August',
#   '20',
#   ',',
#   '2015',
#   'at',
#   '10:16',
#   'AM'],
#  ['What',
#   'Does',
#   'the',
#   'Snapchat',
#   'Data',
#   'Breach',
#   'Mean',
#   'for',
#   'the',
#   'Global',
#   'Big',
#   'Data',
#   'Market',
#   'in',
#   'the',
#   'Retail',
#   'Sec',
#   '...',
#   '<URL>',
#   '#socialmedia',
#   '#happening'],
#  ['RT',
#   '<USR>',
#   ':',
#   '<USR>',
#   'AKO',
#   'HAHAHA',
#   'MAY',
#   'EXAM',
#   'PA',
#   'NGA',
#   'KAMI',
#   'MAGKASUNOD',
#   'NA',
#   'SUBJECT',
#   '!',
#   'HAHAHA',
#   'FIRST',
#   'AND',
#   'SECOND',
#   'PERIOD',
#   'PA',
#   '#ALDUBSaveMaine'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Somerset',
#   'is',
#   '7-1',
#   'on',
#   'games',
#   'played',
#   'on',
#   'a',
#   'Friday',
#   '#GetPatriotic',
#   '<URL>'],
#  ['#NEWS',
#   '#MASHABLE',
#   '|',
#   'Snapchat',
#   'Responds',
#   'to',
#   'New',
#   'Year',
#   "'s",
#   'Eve',
#   'Security',
#   'Breach',
#   '<URL>',
#   '|',
#   '#TECH',
#   '-',
#   '<USR>'],
#  ['1', 'week', 'til', 'my', 'birthday', '!!'],
#  ['"',
#   'I',
#   'hate',
#   'mornings',
#   '.',
#   'One',
#   'of',
#   'these',
#   'days',
#   ',',
#   'i',
#   'will',
#   'watch',
#   'Apollo',
#   'will',
#   'burn',
#   '.',
#   'Ironic',
#   'but',
#   'he',
#   'will',
#   'just',
#   'like',
#   'how',
#   'the',
#   'sun',
#   "'s",
#   'gonna',
#   'set',
#   'off',
#   'someday',
#   '."'],
#  ['<USR>',
#   'he',
#   "'s",
#   'pitching',
#   'Saturday',
#   '.',
#   'He',
#   'had',
#   'a',
#   'really',
#   'good',
#   'year',
#   'in',
#   'AAA-',
#   'he',
#   "'s",
#   'a',
#   'lefty',
#   ',',
#   'they',
#   'can',
#   'last',
#   'forever',
#   '.'],
#  ['The',
#   'Human',
#   'Problem',
#   'at',
#   'the',
#   'Heart',
#   'of',
#   'Snapchat’s',
#   'Employee',
#   'Data',
#   'Breach',
#   '<URL>',
#   'pic.twitter.com/H0nul1eQLq'],
#  ['RT',
#   '<USR>',
#   ':',
#   '2',
#   'days',
#   'left',
#   '.',
#   '#TheIncredibleTrueStory',
#   'available',
#   'everywhere',
#   'Friday',
#   'November',
#   '13th',
#   '.',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'i',
#   'hate',
#   'it',
#   'when',
#   'my',
#   'parents',
#   'want',
#   'me',
#   'to',
#   'come',
#   'home',
#   'early',
#   'from',
#   'a',
#   'party',
#   ',',
#   'but',
#   'i',
#   'wanna',
#   'stay',
#   'really',
#   'late',
#   '#ATeenageThought'],
#  ['RT', '#TBRList', '<URL>'],
#  ['signing', 'along', 'to', 'Remembering', 'Sunday'],
#  ['Anyone',
#   'up',
#   'for',
#   'some',
#   'late',
#   'night',
#   'trivia',
#   'tonight',
#   '?',
#   '10pm',
#   'at',
#   'Summits',
#   '.',
#   'Let',
#   'me',
#   'know',
#   '!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'TIKET',
#   'PROMO',
#   'Ambon',
#   '-',
#   'Jakarta',
#   '|',
#   '1-10',
#   'Feb',
#   '2015',
#   '|',
#   'Info',
#   'klik',
#   '<URL>',
#   '<URL>'],
#  ['Man',
#   'Hospitalized',
#   'After',
#   'Shooting',
#   'on',
#   'Bishop',
#   'Ford',
#   'Freeway',
#   ':',
#   'Police',
#   '<URL>',
#   '…'],
#  ['800,000',
#   'Customers',
#   "'",
#   'detail',
#   'stolen',
#   'in',
#   'Data',
#   'Breach',
#   'at',
#   'French',
#   'Telecom',
#   "'",
#   'Orange',
#   "'",
#   '<URL>',
#   '…',
#   '#Security'],
#  ['joy_redona', '#PushAwardsLizQuens', '<URL>'],
#  ['Hahaha',
#   'wala',
#   'mare',
#   'may',
#   'tweet',
#   'lng',
#   'n',
#   'nkaka',
#   'hb',
#   'hahaha',
#   '<URL>'],
#  ['Every', 'night', '&amp;', 'every', 'day', '!!'],
#  ['$LEG',
#   '-',
#   'SELL',
#   'Signal',
#   'at',
#   '43.34',
#   'on',
#   'Oct',
#   '21',
#   ',',
#   '15',
#   'By',
#   '<URL>',
#   ',',
#   'Trading',
#   'Signals',
#   'Robot',
#   '#stock',
#   '#trading',
#   '#trade',
#   '#investing'],
#  ['RT',
#   '<USR>',
#   ':',
#   '<USR>',
#   'All',
#   'worldly',
#   'cuisines',
#   'are',
#   'Insipid',
#   'in',
#   'front',
#   'of',
#   '#MSG2in447',
#   "'",
#   's',
#   'Elixir',
#   'Thats',
#   'why',
#   'it',
#   'is',
#   '1st',
#   'choice',
#   'of',
#   'millions',
#   '.'],
#  ['Its',
#   'crazy',
#   'that',
#   'one',
#   'day',
#   'I',
#   'have',
#   'energy',
#   'to',
#   'do',
#   'laundry',
#   ',',
#   'mop',
#   'floors',
#   ',',
#   'scrub',
#   'everything',
#   'down',
#   'and',
#   'the',
#   'next',
#   'I',
#   "don't",
#   'even',
#   'feel',
#   'like',
#   'doing',
#   'anything',
#   '!'],
#  ['<USR>',
#   '"',
#   'UGH',
#   'AS',
#   'IF',
#   '"',
#   'pag',
#   'maganda',
#   'si',
#   'Jan',
#   'agad',
#   'pwede',
#   'ako',
#   'muna'],
#  ['Today',
#   'the',
#   'mall',
#   'was',
#   'full',
#   'of',
#   'moms',
#   'who',
#   'love',
#   'scrapbooking',
#   '.',
#   'kill',
#   'me',
#   '.'],
#  ['<USR>',
#   'Heyy',
#   ',',
#   'how',
#   'are',
#   'u',
#   'today',
#   '?',
#   ';)',
#   'follow',
#   '4',
#   'follow',
#   '?'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Will',
#   'you',
#   'be',
#   'wearing',
#   'your',
#   '#lotsofsocks',
#   'tomorrow',
#   'for',
#   'World',
#   'Down',
#   "'s",
#   'Syndrome',
#   'Day',
#   '?',
#   'Natty',
#   'is',
#   '!',
#   '<URL>'],
#  ['So',
#   'much',
#   'violence',
#   '.',
#   '<USR>',
#   'live',
#   'stream',
#   'cuts',
#   'from',
#   'now-finished',
#   'presser',
#   'on',
#   'Cleveland',
#   'shooting',
#   'back',
#   'to',
#   'funeral',
#   'of',
#   'Akron',
#   'officer',
#   'killed',
#   'by',
#   'gunman',
#   '.'],
#  ['<USR>', '<USR>', 'merci', 'mon', 'prince'],
#  ['RT',
#   '<USR>',
#   'Come',
#   'get',
#   'your',
#   'blood',
#   'flowing',
#   'with',
#   '<USR>',
#   '&amp;',
#   '<USR>',
#   'at',
#   'The',
#   'Heartbeat',
#   'tonight',
#   ',',
#   'or',
#   'as',
#   'we',
#   'call',
#   'it',
#   'Hide-and-Go',
#   'Sikh',
#   '!'],
#  ['Just',
#   'puffed',
#   'on',
#   'sour',
#   'd',
#   'unintentionally',
#   '...',
#   "I'm",
#   'so',
#   'high',
#   'Idk',
#   'when',
#   'I',
#   'will',
#   'come',
#   'back',
#   'to',
#   'earth'],
#  ['RT',
#   '<USR>',
#   ':',
#   'B1A4',
#   'releases',
#   'sweet',
#   'teasers',
#   'for',
#   '6th',
#   'mini',
#   'album',
#   "'",
#   'Sweet',
#   "Girl'!",
#   '<URL>'],
#  ['<USR>', 'February', '02', ',', '2015', 'at', '05:03', 'AM', 'post5'],
#  ['Colorado',
#   'Springs',
#   'Police',
#   ':',
#   'Officers',
#   'still',
#   'encountering',
#   'gunfire',
#   'at',
#   'shooting',
#   'site',
#   ':',
#   'Colorado',
#   'Springs',
#   'Police',
#   '...',
#   '<URL>',
#   '#stocks'],
#  ['<USR>',
#   'much',
#   'prefer',
#   'a',
#   'GA',
#   'announcement',
#   'that',
#   'they',
#   'are',
#   'recording',
#   'soon',
#   '.....',
#   'it',
#   'is',
#   'really',
#   'a',
#   'bad',
#   'time',
#   'for',
#   'GA',
#   'fans',
#   'at',
#   'the',
#   'moment',
#   '....',
#   'do',
#   'not',
#   'like',
#   '..'],
#  ['<USR>',
#   '11',
#   'feb',
#   '..',
#   'to',
#   'promote',
#   'his',
#   'film',
#   'with',
#   'jackie',
#   'chan',
#   '"',
#   'dragon',
#   'blade',
#   '"'],
#  ['2',
#   'years',
#   'and',
#   '9',
#   'months',
#   ',',
#   'but',
#   'who',
#   "'s",
#   'counting',
#   '.',
#   'October',
#   '24th',
#   '2017',
#   "can't",
#   'come',
#   'soon',
#   'enough',
#   '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Ashton',
#   'with',
#   'a',
#   'fan',
#   'out',
#   'in',
#   'London',
#   '!',
#   '|',
#   'April',
#   '24',
#   ',',
#   '2015',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'if',
#   'after',
#   'watcing',
#   'this',
#   'you',
#   'dont',
#   'accomplish',
#   'your',
#   'dream',
#   'by',
#   'tomorrow',
#   'idk',
#   'yo',
#   '<URL>'],
#  ['Find',
#   'us',
#   'at',
#   'Tipitina',
#   "'s",
#   'tonight',
#   'and',
#   'mention',
#   'that',
#   "you're",
#   'following',
#   'us',
#   'on',
#   'Twitter',
#   'and',
#   'get',
#   'a',
#   'FREE',
#   'Fried',
#   'Mac',
#   'N',
#   "'",
#   'Cheese',
#   'ball',
#   'with',
#   'any',
#   'order',
#   '!'],
#  ['Tomorrow', 'is', 'another', 'day', '!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Going',
#   'into',
#   'school',
#   'tomorrow',
#   'like',
#   '#KCA',
#   '#Vote1DUK',
#   '<URL>'],
#  ['Spurs',
#   'just',
#   'hit',
#   '+3',
#   '.',
#   'Card',
#   'is',
#   'now',
#   'final',
#   ':',
#   'Tuesday',
#   ':',
#   'Mavs/Rockets',
#   'Under',
#   '222',
#   'Spurs/Clippers',
#   'Under',
#   '205',
#   'Spurs',
#   '+3'],
#  ['Happy',
#   'birfday',
#   'to',
#   'the',
#   'only',
#   'p-i-m-p',
#   'I',
#   'know',
#   '...',
#   '<USR>',
#   '!',
#   'We',
#   "'re",
#   'getting',
#   '"',
#   'white',
#   'boy',
#   'wasted',
#   '"',
#   'tonight',
#   '!'],
#  ["Don't",
#   'know',
#   'if',
#   'I',
#   'should',
#   'actually',
#   'go',
#   'to',
#   'school',
#   'tomorrow'],
#  ['It',
#   'hurts',
#   'like',
#   'there',
#   "'s",
#   'no',
#   'tomorrow',
#   ':(',
#   '(',
#   '#umaARAGALANG',
#   'hahaha',
#   '<URL>'],
#  ['My',
#   'mama',
#   'just',
#   'surprised',
#   'me',
#   'on',
#   'ring',
#   'day',
#   '!!',
#   'Ahh',
#   'today',
#   'just',
#   'got',
#   'so',
#   'much',
#   'better',
#   '!'],
#  ['were',
#   'too',
#   'much',
#   '.',
#   'MJ',
#   'still',
#   'had',
#   'it',
#   'but',
#   'he',
#   'was',
#   '50',
#   'years',
#   'old',
#   'at',
#   'time',
#   '.',
#   'AEG',
#   'just',
#   'wanted',
#   'more',
#   'money',
#   'off',
#   'his',
#   'name',
#   'like',
#   'everyone',
#   'else',
#   '<USR>'],
#  ['<USR>',
#   '2DA',
#   'DEVAL',
#   '.',
#   'YUAN',
#   ',',
#   'ACTIVA',
#   'TSUNAMI',
#   'SUDESTE',
#   'ASIATICO',
#   ',',
#   'CONSOLIDA',
#   'MI',
#   'ANTICIPO',
#   'CLIMAX',
#   'CRASH',
#   'EMERG',
#   '.',
#   'AGO-OCT',
#   '<URL>'],
#  ['Headed',
#   'to',
#   'Davidson',
#   'vs',
#   'Blount',
#   'with',
#   'Bennett-',
#   'love',
#   'spending',
#   'time',
#   'with',
#   'my',
#   'son',
#   '!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Si',
#   'ate',
#   'may',
#   'time',
#   'pang',
#   'ibash',
#   'ako',
#   'ipon',
#   'ka',
#   'na',
#   'lang',
#   'pangpa',
#   'BS',
#   'ng',
#   'LT',
#   'mo',
#   'hehe'],
#  ['RT',
#   '<USR>',
#   ':',
#   'OKC',
#   'outscoring',
#   'Texas',
#   '16-2',
#   'to',
#   'start',
#   'the',
#   '3rd',
#   '...',
#   'Blue',
#   'is',
#   'on',
#   'a',
#   '41-9',
#   'run',
#   'since',
#   'the',
#   '7:54',
#   'mark',
#   'in',
#   'the',
#   '2nd',
#   '.'],
#  ['11:11', 'i', 'wish', 'not', 'to', 'go', 'to', 'school', 'tomorrow'],
#  ['<USR>', '16', 'b', '17', 'in', 'feb'],
#  ['Snapchat',
#   'Responds',
#   'to',
#   'New',
#   'Year',
#   "'s",
#   'Eve',
#   'Security',
#   'Breach',
#   '<URL>',
#   '#news'],
#  ['<USR>', 'for', 'thursday', 'right', 'lol'],
#  ['Final', 'grades', 'go', 'up', 'tomorrow', ':('],
#  ['workin',
#   'at',
#   'the',
#   'ol',
#   'Sunset',
#   'Bistro',
#   'tonight',
#   '...',
#   'come',
#   'get',
#   'some',
#   'grub'],
#  ['7',
#   'people',
#   'injured',
#   'in',
#   'Indianapolis',
#   'shooting',
#   '(',
#   'from',
#   '<USR>',
#   '.',
#   '<URL>',
#   '…'],
#  ['Happy', 'Tuesday', ',', 'everyone', '!', '<URL>'],
#  ['photographing',
#   'the',
#   'midway',
#   'tonight',
#   '..',
#   'should',
#   'be',
#   'fun',
#   '..',
#   'lots',
#   'of',
#   'fun',
#   'lights',
#   '!!',
#   'makes',
#   'for',
#   'great',
#   'photos',
#   '..',
#   'like',
#   'this',
#   'one',
#   '..',
#   '<URL>'],
#  ['Praying',
#   'for',
#   'families/students',
#   'in',
#   'Marysville',
#   'School',
#   'shooting'],
#  ['<USR>',
#   'its',
#   'okay',
#   'then',
#   '..',
#   'make',
#   'it',
#   'when',
#   'it',
#   'works',
#   ':D'],
#  ['Raiders',
#   'trailing',
#   '41-33',
#   'as',
#   'we',
#   'head',
#   'to',
#   'the',
#   '4th',
#   'qtr',
#   '.'],
#  ['So',
#   'ready',
#   'for',
#   'my',
#   'first',
#   'day',
#   'of',
#   'this',
#   'new',
#   'job',
#   'tomorrow',
#   'bruh'],
#  ['(',
#   'OH',
#   ')',
#   'Severe',
#   'Thunderstorm',
#   'Warning',
#   'issued',
#   'May',
#   '11',
#   'at',
#   '7:53',
#   'PM',
#   'EDT',
#   'until',
#   'May',
#   '11',
#   'at',
#   '8:00',
#   'PM',
#   'EDT',
#   'by',
#   'NWS',
#   '<URL>',
#   '#ohwx'],
#  ['Greatest', 'place', 'on', 'Earth', '!!', '<URL>'],
#  ['football',
#   'game',
#   'tonight',
#   '!',
#   'ahh',
#   'im',
#   'so',
#   'nervous',
#   'about',
#   'our',
#   'dance',
#   '!!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Dr',
#   '.',
#   'Dre',
#   "'s",
#   'new',
#   'album',
#   'featuring',
#   'Kendrick',
#   ',',
#   'Eminem',
#   ',',
#   'Snoop',
#   'Dogg',
#   '&amp;',
#   'more',
#   'drops',
#   'this',
#   'Friday',
#   '<URL>'],
#  ['Its',
#   '3',
#   "o'clock",
#   'on',
#   'my',
#   'first',
#   'day',
#   'in',
#   'Vegas',
#   'and',
#   'I',
#   'am',
#   'already',
#   'drunk',
#   'and',
#   'just',
#   'sang',
#   'meatloaf',
#   'at',
#   'karoke',
#   '.'],
#  ['RT',
#   'mixcloud',
#   ':',
#   '#EDM',
#   'kingpin',
#   'TomParker',
#   "'",
#   's',
#   'December',
#   'mix',
#   ':',
#   '<URL>',
#   '<URL>'],
#  ['Crab', 'Fest', 'finna', 'swole', 'on', 'Sat'],
#  ['I', 'gotta', 'work', 'at', '10', 'tomorrow', 'morning', '.'],
#  ['its', 'time', 'for', 'the', 'devil', 'to', 'dance', '.', '.', '.'],
#  ['Friday',
#   'deal',
#   '!',
#   'Save',
#   '30%',
#   'on',
#   'select',
#   'new',
#   'arrivals',
#   'by',
#   '<USR>',
#   '.',
#   'Check',
#   'it',
#   'out',
#   '!',
#   '<URL>'],
#  ['<USR>',
#   'Sorry',
#   ',',
#   'Jan',
#   '.',
#   "I'll",
#   'try',
#   'to',
#   'do',
#   'better',
#   'next',
#   'time',
#   'lol',
#   '.'],
#  ['#ICO',
#   'complain',
#   '#talktalk',
#   'complete',
#   'data',
#   'breach',
#   'online',
#   'form',
#   '<URL>',
#   'because',
#   'they',
#   'could',
#   'have',
#   'responded',
#   'quicker',
#   'using',
#   'phone',
#   '#fail'],
#  ['Breaking',
#   'News',
#   ':',
#   'Shooting',
#   'at',
#   'the',
#   'Washington',
#   'Navy',
#   'Yard',
#   '<URL>'],
#  ['Snapchat',
#   'Apologizes',
#   'for',
#   'Data',
#   'Breach',
#   ',',
#   'Updates',
#   'App',
#   'to',
#   'Fix',
#   'Find',
#   'Friends',
#   'Feature',
#   ':',
#   'The',
#   'popular',
#   'app',
#   'for',
#   'sharing',
#   'shor',
#   '...',
#   '<URL>'],
#  ['Today',
#   'is',
#   'goin',
#   'to',
#   'slow',
#   'at',
#   'work',
#   '...',
#   "Can't",
#   'wait',
#   'to',
#   'get',
#   'this',
#   'weekend',
#   'started',
#   '!!!'],
#  ['Good',
#   'luck',
#   'on',
#   'your',
#   'finals',
#   '!',
#   'Practice',
#   'schedule',
#   'for',
#   'the',
#   'week',
#   ':',
#   'Monday-Wednesday',
#   'starting',
#   'at',
#   '12:00',
#   'pm',
#   '.',
#   'Spread',
#   'the',
#   'word',
#   '.',
#   '<URL>'],
#  ['Wow',
#   '!..',
#   'Michael',
#   'Owen',
#   'jwus',
#   'just',
#   'ask',
#   'who',
#   'he',
#   'think',
#   'will',
#   'finish',
#   'in',
#   'top',
#   'four',
#   'as',
#   '3rd',
#   'and',
#   '4th',
#   '..',
#   'he',
#   'said',
#   'LFC',
#   '&amp;',
#   'MUFC',
#   '.',
#   'smh',
#   '..',
#   'he',
#   'is',
#   'such',
#   'an',
#   'bias',
#   'assole',
#   '.'],
#  ['Hell', 'yeh', '1st', 'day', 'of', 'vacation', '!!!!!'],
#  ['BREACH', '!', 'CHINA', 'HACKING', 'DESPITE', 'DEAL', '.', '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'When',
#   'trey',
#   'songz',
#   'was',
#   'a',
#   'kid',
#   'his',
#   'mother',
#   'probably',
#   'went',
#   'did',
#   'you',
#   'do',
#   'your',
#   'homework',
#   '?',
#   'And',
#   'he',
#   'probably',
#   'went',
#   '#YUPPP',
#   'lol'],
#  ["C'mon", 'Jeremy', 'Ross'],
#  ['Curious',
#   'to',
#   'see',
#   'who',
#   'City',
#   'buy',
#   'in',
#   'January',
#   '.',
#   'They',
#   'need',
#   'a',
#   'striker',
#   'desperately',
#   '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Your',
#   '#Cochrane',
#   'Eagle',
#   'front',
#   'for',
#   'April',
#   '23',
#   ',',
#   '2015',
#   '.',
#   '<URL>'],
#  ['Happy',
#   'Wednesday',
#   'Off',
#   'the',
#   'record',
#   'for',
#   'now',
#   ',',
#   'show',
#   '<USR>',
#   '7AM',
#   '<URL>',
#   '#blab'],
#  ['I',
#   'want',
#   'it',
#   'NOW',
#   '!',
#   ';)',
#   'RT',
#   ':',
#   '<USR>',
#   'Pumpkin',
#   'Moonshine',
#   'has',
#   'arrived',
#   'in',
#   'Nashville',
#   '--',
#   'Give',
#   'it',
#   'a',
#   'week',
#   'to',
#   'get',
#   'it',
#   'in',
#   'stores',
#   '.',
#   'KY',
#   'ships',
#   'next',
#   'week',
#   '!'],
#  ['<USR>',
#   'lol',
#   "I'm",
#   'not',
#   'up',
#   'to',
#   'much',
#   "I'm",
#   'just',
#   'off',
#   'to',
#   'bed',
#   'lol',
#   'had',
#   'a',
#   'long',
#   'day',
#   'cht',
#   'tumoz',
#   ':)'],
#  ['RT',
#   '<USR>',
#   'If',
#   'you',
#   'feel',
#   'as',
#   'though',
#   'your',
#   'company',
#   'is',
#   'having',
#   'problems',
#   'generating',
#   'sales',
#   ',',
#   'it',
#   'might',
#   'be',
#   'time',
#   'to',
#   'bring',
#   'in',
#   'a',
#   'sales',
#   'training',
#   'speaker',
#   '.'],
#  ['sept', '#VoteLauraMarano', '#KCA'],
#  ['Put',
#   'the',
#   'tree',
#   'up',
#   "I'll",
#   'wrap',
#   'gifts',
#   'and',
#   'decorate',
#   'it',
#   'tomorrow',
#   "I'm",
#   'tired'],
#  ['<USR>',
#   'hey',
#   'i',
#   'gotta',
#   'ask',
#   'you',
#   'something',
#   'if',
#   'i',
#   'can',
#   ':)',
#   'please',
#   'tweet',
#   'me',
#   'when',
#   'you',
#   'be',
#   'online',
#   'and',
#   "i'll",
#   'send',
#   'you',
#   'DM',
#   '.',
#   'okkk',
#   '?',
#   'thank',
#   'you'],
#  ['Phew', '!!', 'at', 'least', 'a', 'Friday', 'without', 'exams', '.', ':)'],
#  ['Off',
#   'work',
#   'I',
#   'guess',
#   '?',
#   'Told',
#   'to',
#   'leave',
#   'an',
#   'hour',
#   'and',
#   'half',
#   'before',
#   'I',
#   'was',
#   'scheduled',
#   'to',
#   '.',
#   'My',
#   'paycheck',
#   'is',
#   'going',
#   'to',
#   'be',
#   'weak',
#   '.',
#   'Not',
#   'happy',
#   '.'],
#  ['Why',
#   'hate',
#   'on',
#   'somebody',
#   'for',
#   'doing',
#   'well',
#   'when',
#   'you',
#   'can',
#   'simply',
#   'say',
#   'great',
#   'job',
#   'and',
#   'move',
#   'on',
#   '..',
#   '[Haters',
#   'u',
#   'can',
#   'kill',
#   'yourself',
#   ']',
#   'cuz',
#   'ur',
#   'losers'],
#  ['RT',
#   '<USR>',
#   ':',
#   'no',
#   'money',
#   'november',
#   'is',
#   'going',
#   'a',
#   'little',
#   'too',
#   'well'],
#  ['Zendesk', 'security', 'breach', '.', '<URL>'],
#  ['I',
#   'have',
#   'eaten',
#   'a',
#   'large',
#   'quantity',
#   'of',
#   'oranges',
#   'this',
#   'week',
#   '...'],
#  ['chinese',
#   'food',
#   '..',
#   'stayin',
#   'in',
#   'for',
#   'tonight',
#   'but',
#   'goin',
#   'to',
#   'the',
#   'archery',
#   'range',
#   'either',
#   'tomorrow',
#   'or',
#   'sunday'],
#  ['<USR>',
#   'haha',
#   'it',
#   "'s",
#   'not',
#   'that',
#   'bad',
#   'now',
#   'but',
#   'when',
#   'i',
#   'was',
#   'little',
#   'i',
#   'used',
#   'to',
#   'freak',
#   'out',
#   'so',
#   'i',
#   'would',
#   'use',
#   'the',
#   'chewables',
#   'that',
#   'tasted',
#   'like',
#   'chalk',
#   '.'],
#  ['kathnielmeoww', ':', '#PushAwardsKathNiels', '<URL>'],
#  ['Iran',
#   'Quds',
#   'chief',
#   'visited',
#   'Russia',
#   'in',
#   'breach',
#   'of',
#   'UN',
#   'travel',
#   'ban',
#   ':',
#   'sources',
#   'IranTalks',
#   'IranDeal',
#   '<URL>'],
#  ['<USR>',
#   'awww',
#   'he',
#   "'s",
#   'in',
#   'the',
#   'rocky',
#   'horror',
#   'show',
#   'next',
#   'week',
#   'which',
#   'means',
#   'he',
#   "'s",
#   'gotta',
#   'wear',
#   'stockings',
#   'an',
#   'suspenders',
#   'lol',
#   ':P'],
#  ['Williams',
#   'is',
#   'running',
#   'up',
#   'and',
#   'down',
#   'the',
#   'field',
#   '.',
#   'You',
#   'take',
#   'him',
#   'out',
#   'for',
#   '3',
#   'plays',
#   'on',
#   'the',
#   '1',
#   '.',
#   'You',
#   'give',
#   'it',
#   'to',
#   'him',
#   'on',
#   '3rd',
#   'and',
#   'goal',
#   'from',
#   'the',
#   '6',
#   '.',
#   '?????'],
#  ['May',
#   'Paalam',
#   'alam',
#   'ka',
#   'pang',
#   'Forever',
#   ':P',
#   'Walang',
#   'F_O_R_E_V_E_R'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Toltec',
#   'Warriors',
#   '10th-12th',
#   'century',
#   'CE',
#   'Tollan',
#   '(',
#   'Tula',
#   ')',
#   '#Mexico',
#   '#archaeology',
#   'By',
#   'Luidger',
#   '<URL>'],
#  ['Yahoo',
#   ':',
#   'Jackie',
#   'joins',
#   'Twitter',
#   '50',
#   'years',
#   'after',
#   'JFK',
#   'campaign',
#   ':',
#   'Had',
#   'Twitter',
#   'been',
#   'an',
#   'option',
#   'in',
#   '1960',
#   ',',
#   'a',
#   'pregnant',
#   'Jacquelin',
#   '...',
#   '<URL>'],
#  ['Twitter',
#   ',',
#   'Pinterest',
#   'and',
#   'Tumblr',
#   'Notify',
#   'of',
#   'Security',
#   'Breach',
#   'After',
#   'Zendesk',
#   'Hack',
#   ':',
#   'Twitter',
#   ',',
#   'Pinterest',
#   'an',
#   '...',
#   '<URL>',
#   '[',
#   '#social',
#   ']'],
#  ['RT',
#   '<USR>',
#   ':',
#   'trending',
#   'at',
#   '1st',
#   'like',
#   'a',
#   'boss',
#   '#HBDDearVIJAY'],
#  ['<USR>',
#   'Have',
#   'a',
#   'lovely',
#   'day',
#   'and',
#   'take',
#   'lots',
#   'of',
#   'inappropriate',
#   'photos',
#   '!',
#   '*bg*'],
#  ['RT',
#   '<USR>',
#   ':',
#   'How',
#   'I',
#   'feel',
#   'the',
#   'Monday',
#   'after',
#   'the',
#   'Super',
#   'Bowl',
#   '<URL>'],
#  ['You',
#   'may',
#   'attempt',
#   'to',
#   'simplify',
#   'complex',
#   'relationship',
#   'dynamics',
#   'toda',
#   '...',
#   'More',
#   'for',
#   'Aquarius',
#   '<URL>'],
#  ['.',
#   '<USR>',
#   'Heading',
#   'Wildlife',
#   'Corruption',
#   '1st',
#   'stop',
#   'CITES',
#   'corrupt',
#   'permits',
#   'for',
#   '#China',
#   'Zimbabwe',
#   'Gov',
#   'attacks',
#   'elephants',
#   '#SaveAfricanAnimals'],
#  ['<USR>',
#   'Awesome',
#   '!',
#   'First',
#   'episode',
#   'goes',
#   'up',
#   'two',
#   'weeks',
#   'from',
#   'Monday',
#   '.',
#   'Hope',
#   'it',
#   'meets',
#   'your',
#   'expectations',
#   '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   'off',
#   'dulu',
#   'babay',
#   ':',
#   '*',
#   'H-26',
#   '19TH',
#   'RIZKIRIDHO'],
#  ['RT',
#   '<USR>',
#   ':',
#   'It',
#   "'s",
#   'Yom',
#   'Kippur',
#   'eve',
#   ',',
#   'so',
#   'it',
#   "'s",
#   'the',
#   'time',
#   'to',
#   'apologize',
#   'to',
#   'anyone',
#   "I've",
#   'wronged',
#   '.',
#   'Hopefully',
#   ',',
#   "you're",
#   'on',
#   'Twitter',
#   '.',
#   'Sorry',
#   '!'],
#  ['let',
#   "'s",
#   'go',
#   'crazy',
#   'crazy',
#   'crazy',
#   'till',
#   'we',
#   'see',
#   'the',
#   'sun',
#   'i',
#   'know',
#   'we',
#   'only',
#   'met',
#   'but',
#   'let',
#   "'s",
#   'pretend',
#   'it',
#   "'s",
#   'love'],
#  ['<USR>', 'when', 'you', 'coming', 'to', 'grandma', 'house', '?'],
#  ['TWITTER',
#   'SHOUT',
#   'OUT',
#   'TIME',
#   '!',
#   'RT',
#   'to',
#   'enter',
#   '!',
#   'I',
#   'will',
#   'pick',
#   '10',
#   'winners',
#   '!',
#   'Contest',
#   'ends',
#   'on',
#   'Friday',
#   '21',
#   'August',
#   '2015',
#   '!'],
#  ['Someone',
#   'may',
#   'rain',
#   'on',
#   'your',
#   'parade',
#   'today',
#   ',',
#   'or',
#   'you',
#   'might',
#   'just',
#   'feel',
#   '...',
#   'More',
#   'for',
#   'Cancer',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Bakit',
#   'kc',
#   'di',
#   'nyo',
#   'inabutan',
#   'si',
#   'jea',
#   'ng',
#   'towel',
#   'o',
#   'tissue',
#   '..',
#   'eh',
#   'di',
#   'sana',
#   'may',
#   'punasan',
#   'na',
#   'nangyare',
#   '...',
#   'hahaha'],
#  ['Aptos',
#   'CA',
#   '-',
#   'Chemistry',
#   'Tutoring/Teaching',
#   '-',
#   'I',
#   'have',
#   'a',
#   'daughter',
#   'in',
#   '10th',
#   'grade',
#   'and',
#   'she',
#   'has',
#   'been',
#   'needing',
#   'help',
#   'with',
#   'he',
#   '...',
#   '<URL>'],
#  ['time',
#   'to',
#   'get',
#   'some',
#   'sleep',
#   '.',
#   'been',
#   'out',
#   'from',
#   '4pm',
#   'till',
#   'now',
#   '.'],
#  ['Maybe',
#   'it',
#   "'s",
#   'compulsary',
#   '..',
#   'when',
#   "you're",
#   'over',
#   'the',
#   'age',
#   'of',
#   '30',
#   'and',
#   'an',
#   'unemployed',
#   'wrestler',
#   'you',
#   'have',
#   'to',
#   'act',
#   'like',
#   'a',
#   'total',
#   'tool',
#   '.',
#   '<URL>'],
#  ['Justin',
#   'Timberlake',
#   'ft',
#   '.',
#   'Beyonce',
#   '-',
#   'Until',
#   'the',
#   'End',
#   'of',
#   'Time',
#   '<URL>',
#   'via',
#   '<USR>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Mere',
#   'sainyaa',
#   'superstar',
#   '.',
#   '~',
#   'Sun',
#   "'s",
#   'wife'],
#  ['Lindsay',
#   'Lohan',
#   'allegedly',
#   'failed',
#   'her',
#   'drug',
#   'test',
#   '.',
#   'So',
#   'not',
#   'fetch',
#   '.',
#   'Quick',
#   ',',
#   'let',
#   "'s",
#   'all',
#   'put',
#   'on',
#   'our',
#   'shocked',
#   'faces',
#   'that',
#   '23',
#   'days',
#   'of',
#   'rehab',
#   "didn't",
#   'work',
#   '!'],
#  ['<USR>',
#   '1st',
#   'tym',
#   'i',
#   'hve',
#   'seen',
#   'that',
#   'dhoni',
#   'taking',
#   'out',
#   'bowler',
#   'from',
#   'attack',
#   '#cwc2015',
#   '#IndVSire'],
#  ['Why',
#   "doesn't",
#   'my',
#   'vehicle',
#   'have',
#   'a',
#   'spare',
#   'tire',
#   '?',
#   'Your',
#   'car',
#   'may',
#   'be',
#   'equipped',
#   'with',
#   'run-flat',
#   'tires',
#   '.',
#   'Newer',
#   'BMW',
#   'and',
#   'MINI',
#   'tend',
#   '...',
#   '<URL>'],
#  ['waiting',
#   'one',
#   'extra',
#   'day',
#   'was',
#   'a',
#   'STUPID',
#   'IDEA',
#   'because',
#   'now',
#   'everything',
#   'is',
#   'super',
#   'expensive',
#   'AAAAAHHH',
#   '.',
#   'x_x',
#   '*freakingoutkhsf*'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Last',
#   'day',
#   'of',
#   'this',
#   'season',
#   '!!!',
#   'Next',
#   'season',
#   'I',
#   'hope',
#   "I'm",
#   'driving',
#   'myself',
#   'to',
#   'work',
#   '!',
#   'Gonna',
#   'miss',
#   'everybody',
#   'like',
#   'crazy',
#   ':)'],
#  ['No',
#   'tips',
#   'from',
#   'me',
#   'tomorrow',
#   'on',
#   'the',
#   'fizzy',
#   'stuff',
#   'back',
#   'Craigs',
#   'he',
#   'may',
#   'do',
#   'well',
#   'without',
#   'me',
#   'jinxing',
#   'them',
#   '.'],
#  ['<USR>',
#   'WELL',
#   'SORRRY',
#   '!!',
#   'I',
#   'did',
#   "n't",
#   'know',
#   'you',
#   'YEARS',
#   'AGO',
#   '!'],
#  ['Just',
#   'played',
#   ':',
#   'Shaking',
#   'the',
#   'Mote',
#   '-',
#   'The',
#   'Kissaway',
#   'Trail',
#   '-',
#   'Breach',
#   '.',
#   'mp3(unknown',
#   ')'],
#  ['October', 'is', 'Human', 'Rights', 'Month', '!', '#yconline', '<URL>'],
#  ['A',
#   'Hughie',
#   "O'Donoghue",
#   'painting',
#   ',',
#   'some',
#   'great',
#   'curvy',
#   'pots',
#   'and',
#   'intricately',
#   'illuminated',
#   'Persian',
#   'books',
#   '..',
#   'time',
#   'well',
#   'spent',
#   'in',
#   'the',
#   'Fitzwilliam',
#   '.'],
#  ['#Ingress', '#RedFaction', '<URL>'],
#  ['<USR>',
#   'it',
#   "'s",
#   'cool',
#   'also',
#   "I'm",
#   'not',
#   'sure',
#   '.',
#   'If',
#   'I',
#   'were',
#   'you',
#   "I'd",
#   'renew',
#   'right',
#   'away',
#   'before',
#   'but',
#   'if',
#   'not',
#   "I'd",
#   'still',
#   'try',
#   '.',
#   'Best',
#   'of',
#   'luck'],
#  ['<USR>',
#   'I',
#   'got',
#   'slapped',
#   'in',
#   'the',
#   'face',
#   'the',
#   'other',
#   'day',
#   'by',
#   'a',
#   'few',
#   'DT',
#   'fans',
#   'because',
#   'I',
#   'said',
#   'you',
#   'were',
#   'awesome',
#   'for',
#   'joining',
#   'A7X',
#   '.',
#   'So',
#   'worth',
#   'it',
#   '.',
#   'foREVer',
#   '!'],
#  ['RT', '<USR>', ':', "C'mon", 'Cavs', '!'],
#  ['Your',
#   'foggy',
#   'brain',
#   'may',
#   'cloud',
#   'your',
#   'thinking',
#   'today',
#   ',',
#   'but',
#   'you',
#   'can',
#   'ma',
#   '...',
#   'More',
#   'for',
#   'Gemini',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Getting',
#   'ready',
#   'for',
#   'our',
#   'final',
#   'new',
#   'show',
#   'of',
#   '2014',
#   '.',
#   'Gonna',
#   'be',
#   'a',
#   'good',
#   'one',
#   '--',
#   'Amy',
#   'Adams',
#   'and',
#   '<USR>',
#   'Saturday',
#   '!',
#   '#SNL'],
#  ['RT',
#   '<USR>',
#   ':',
#   'when',
#   'u',
#   'realize',
#   'schools',
#   'tomorrow',
#   'and',
#   'u',
#   "haven't",
#   'started',
#   'ur',
#   'hw',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'good',
#   'morning',
#   'or',
#   'good',
#   'afternoon',
#   '-',
#   'Sunday'],
#  ['Up',
#   'to',
#   '14',
#   'people',
#   'dead',
#   'in',
#   'San',
#   'Bernardino',
#   'shooting',
#   ':',
#   'police',
#   '<URL>'],
#  ['Redi',
#   ':D',
#   '"',
#   '<USR>',
#   ':',
#   'Are',
#   'ready',
#   'wolf',
#   '?',
#   'We',
#   'can',
#   'perfom',
#   'at',
#   "'",
#   'the',
#   'launching',
#   '#1st',
#   '<USR>',
#   '\'"'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Two',
#   'EXO',
#   'members',
#   'will',
#   'attend',
#   'KBS',
#   'KPOP',
#   'PLANET',
#   ',',
#   'advanced',
#   'radio',
#   'variety',
#   'program',
#   'on',
#   '3rd',
#   'May',
#   'for',
#   'one',
#   'hour',
#   '.',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'When',
#   'people',
#   'try',
#   'to',
#   'say',
#   'how',
#   'mean',
#   'and',
#   'harsh',
#   'God',
#   'was',
#   ',',
#   'remind',
#   'them',
#   'the',
#   'true',
#   'nature',
#   'of',
#   'God',
#   'came',
#   'in',
#   'the',
#   'person',
#   'of',
#   'Jesus',
#   'Christ'],
#  ['"',
#   'SendGrid',
#   'Email',
#   'Breach',
#   'Was',
#   'Used',
#   'to',
#   'Attack',
#   'Coinbase',
#   ',',
#   'a',
#   'Bitcoin',
#   'Exchange',
#   '"',
#   'by',
#   'NICOLE',
#   'PERLROTH',
#   'via',
#   'NYT',
#   '<URL>'],
#  ['Is',
#   'it',
#   'cricket',
#   'season',
#   '?',
#   "I've",
#   'killed',
#   'about',
#   '20',
#   'in',
#   'the',
#   'laundry',
#   'room',
#   'in',
#   'the',
#   'past',
#   'week',
#   '.'],
#  ['even', 'better', 'than', 'cocktail', 'friday', '!', '<URL>'],
#  ['EU',
#   'will',
#   'add',
#   'c19',
#   'names',
#   'to',
#   'Ukraine',
#   'sanctions',
#   'list',
#   'on',
#   'Mon',
#   '.',
#   'No',
#   'proposals',
#   'yet',
#   'on',
#   'new',
#   'economic',
#   'measures',
#   '.',
#   'Arming',
#   'Kiev',
#   'up',
#   'to',
#   'nat',
#   'capitals',
#   'not',
#   'EU'],
#  ['Important',
#   'principles',
#   'may',
#   ',',
#   'and',
#   'must',
#   ',',
#   'be',
#   'inflexible',
#   '.',
#   '-',
#   'Abe',
#   'Lincoln'],
#  ['BANANA', '!', '<URL>'],
#  ['<USR>',
#   'hopefully',
#   'will',
#   'be',
#   'anyway',
#   ',',
#   'might',
#   'go',
#   'just',
#   'the',
#   'Saturday'],
#  ['2nd', 'favoryits', 'to', 'win', 'the', 'World', 'Cup', 'mind'],
#  ['On',
#   'Thursday',
#   '22',
#   ',',
#   "'",
#   'Astoria',
#   "'",
#   'was',
#   'Trending',
#   'Topic',
#   'in',
#   'Vancouver',
#   'for',
#   '4',
#   'hours',
#   ':',
#   '<URL>',
#   '#trndnl'],
#  ['x1x_ne_x1x',
#   '<URL>',
#   'September',
#   '27',
#   ',',
#   '2015',
#   'at',
#   '02:04',
#   'AM',
#   '3'],
#  ['Facial',
#   'hair',
#   'may',
#   'have',
#   'to',
#   'go',
#   'in',
#   'the',
#   'next',
#   'few',
#   'days',
#   '.',
#   "We'll",
#   'see',
#   '...'],
#  ['History',
#   'exam',
#   ':',
#   'cite',
#   'two',
#   'causes',
#   'of',
#   '1st',
#   'World',
#   'War',
#   '.',
#   '1',
#   ')',
#   'The',
#   'quantum',
#   'wavefunction',
#   ';',
#   '2',
#   ')',
#   'The',
#   'initial',
#   'conditions',
#   'of',
#   'the',
#   'Universe',
#   'via',
#   '<USR>'],
#  ['null', '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'OFFICIAL',
#   'HASHTAG',
#   ':',
#   'FRIDAY',
#   '<USR>',
#   '<USR>',
#   '<USR>',
#   '#ALDUBTrust',
#   '<URL>'],
#  ['<USR>',
#   '<USR>',
#   'Christmas',
#   "wouldn't",
#   'be',
#   'in',
#   'December',
#   'if',
#   'it',
#   "wasn't",
#   'for',
#   'them',
#   ';)'],
#  ['Friday',
#   'night',
#   'is',
#   'the',
#   'best',
#   'cus',
#   'u',
#   'know',
#   'the',
#   'nest',
#   'day',
#   'u',
#   'can',
#   'rest',
#   '!!!!!',
#   ':D'],
#  ['Hannah', "'s", "'", 'We', 'Can', 'For', 'BPAN', "'", 'Campaign', '<URL>'],
#  ['<USR>', '<URL>'],
#  ['Man',
#   'charged',
#   'in',
#   'shooting',
#   'of',
#   '5-year-old',
#   'boy',
#   ':',
#   'Authorities',
#   'charged',
#   'a',
#   '24-year-old',
#   'man',
#   'with',
#   'shooting',
#   'a',
#   '...',
#   '<URL>',
#   '#Chicago',
#   '#News'],
#  ['Who', "'s", 'pumped', 'for', 'the', '2nd', 'half', '?'],
#  ['RT',
#   'JaDineLoveteam',
#   ':',
#   'Kainis',
#   '.',
#   'Ngayon',
#   'lang',
#   'ako',
#   'nakapag',
#   'flood',
#   'ng',
#   'tweets',
#   '.',
#   'Bat',
#   'kasi',
#   'may',
#   'tweet',
#   'limit',
#   'pa',
#   '?',
#   '#OTWOLStartOver',
#   '#PushAwardsJaDines'],
#  ['Developing',
#   '&amp;',
#   'Implementing',
#   'Dance',
#   'Curricula-B',
#   'starts',
#   'Monday',
#   '.',
#   'It',
#   "'s",
#   'not',
#   'to',
#   'late',
#   'to',
#   'register',
#   '!',
#   '<URL>'],
#  ['Local',
#   'reports',
#   ':',
#   'Drive-by',
#   'shooting',
#   'wounds',
#   '11',
#   'in',
#   'Washington',
#   ',',
#   'DC',
#   '<URL>',
#   '#guncrisis'],
#  ['Not',
#   'only',
#   'is',
#   'it',
#   '#BattlestarGalactica',
#   "'s",
#   '32nd',
#   'Anniversary',
#   ',',
#   'tonite',
#   'is',
#   'the',
#   '3rd',
#   'season',
#   'premiere',
#   'of',
#   '#StarWars',
#   '#TheCloneWars',
#   '!!'],
#  ['#Sunday',
#   '#Art',
#   'Dirk',
#   'Walker',
#   ':',
#   '#Jesus',
#   'Heals',
#   'a',
#   'Bleeding',
#   'Woman',
#   '#Catholic',
#   '#gospel',
#   '<URL>'],
#  ['<USR>',
#   'au',
#   'secours',
#   'Svp',
#   '!!!!',
#   "T'as",
#   'trop',
#   "d'espoir",
#   'mon',
#   'grand',
#   "c'est",
#   'ouf'],
#  ['RT',
#   '<USR>',
#   ':',
#   '58',
#   'years',
#   'ago',
#   'today',
#   'I',
#   'tumbled',
#   'from',
#   'my',
#   'mother',
#   "'s",
#   'womb',
#   'with',
#   'a',
#   'cigarette',
#   'in',
#   'my',
#   'mouth',
#   'and',
#   'a',
#   'chihuahua',
#   'puppy',
#   'under',
#   'each',
#   'arm',
#   '...'],
#  ['Halloween',
#   'is',
#   'TOMORROW',
#   ',',
#   'but',
#   'that',
#   "doesn't",
#   'mean',
#   'you',
#   "can't",
#   'snag',
#   'a',
#   'great',
#   'deal',
#   'on',
#   'our',
#   'Halloween',
#   'products',
#   '!',
#   'Hurry',
#   ',...',
#   '<URL>'],
#  ['<USR>',
#   'Selling',
#   'Saturday',
#   'and',
#   'Sunday',
#   'Wireless',
#   'tickets',
#   'for',
#   'well',
#   'under',
#   'cost',
#   'price',
#   '!',
#   'DM',
#   'me',
#   'for',
#   'prices',
#   'ASAP',
#   '!!',
#   '#vibetickets'],
#  ['<USR>', 'jan', 'lupa', 'makan', 'nde'],
#  ['<USR>',
#   'Rabu',
#   ',',
#   '09',
#   'September',
#   '2015',
#   'Jam',
#   '01:28',
#   '#AutoFreeFollowers'],
#  ['#Offline',
#   'For',
#   'along',
#   'time',
#   '...',
#   'maybe',
#   'not',
#   'until',
#   'tomorrow'],
#  ['<USR>',
#   'good',
#   'luck',
#   'with',
#   'the',
#   'audition',
#   'Saturday',
#   '.',
#   'Remember',
#   'positive',
#   'thoughts',
#   '!!!!!'],
#  ['Day',
#   '27',
#   '-',
#   'Day',
#   '27-',
#   'Why',
#   'are',
#   'you',
#   'doing',
#   'this',
#   '30',
#   'day',
#   'challenge',
#   'im',
#   'doing',
#   'this',
#   'because',
#   'i',
#   'am',
#   'bored',
#   ':)',
#   '<URL>'],
#  ['Kitty', "'s", '1st', '#yoga', 'mat', '.', '<USR>', '#margaret', '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'If',
#   'this',
#   'tweet',
#   'can',
#   'reach',
#   'whopping',
#   '1,000',
#   'retweets',
#   ',',
#   "I'll",
#   'announce',
#   'one',
#   'of',
#   'our',
#   'two',
#   'projects',
#   'debuting',
#   'this',
#   'Friday',
#   '.'],
#  ['Is',
#   'this',
#   'like',
#   'No',
#   'cutting',
#   'hair',
#   'December',
#   '??',
#   'PEOPLE',
#   'NEED',
#   'TO',
#   'GET',
#   'THEIR',
#   'HAIR',
#   'CUT',
#   'BEFORE',
#   'I',
#   'USE',
#   'A',
#   'GRASS',
#   'CUTTER',
#   'TO',
#   'SHAVE',
#   'IT',
#   'ALL',
#   'OFF',
#   '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   "J'ai",
#   'enfin',
#   'mon',
#   'nouveau',
#   'tel',
#   '#MTVStars',
#   'One',
#   'Direction'],
#  ['Its',
#   'clear',
#   'and',
#   '104&amp;#xB0',
#   ';',
#   'F',
#   '-',
#   'Humidity',
#   ':',
#   '7&amp;#x25',
#   ';',
#   '25',
#   '-',
#   'Dew',
#   'Pnt',
#   ':',
#   '28&amp;#xB0',
#   ';',
#   'F',
#   '-',
#   'Wind',
#   ':',
#   'WNW',
#   'at',
#   '9mph',
#   '-',
#   'Rain',
#   'so',
#   'far',
#   'today',
#   ':',
#   '0.00',
#   '-',
#   '<URL>',
#   '#wxob'],
#  ['Monster',
#   'Strike',
#   'Web',
#   'Anime',
#   "'s",
#   '2nd',
#   'Trailer',
#   'Profiles',
#   'Characters',
#   '<URL>'],
#  ['Salut',
#   ',',
#   'moi',
#   'sa',
#   'va',
#   'beaucoup',
#   'mieux',
#   '.',
#   'Comme',
#   'vous',
#   'pouvez',
#   'le',
#   'contater',
#   ',',
#   'mon',
#   'compte',
#   'Twitter',
#   'retrouve',
#   'tout',
#   'les',
#   'abonnements',
#   "qu'il",
#   'avait',
#   'perdu',
#   '.',
#   'Peace',
#   '.'],
#  ['e',
#   'o',
#   'q',
#   'vai',
#   'ser',
#   'hj',
#   '?',
#   'cerveja',
#   'foi',
#   'ontem',
#   '...',
#   'que',
#   'tal',
#   'um',
#   'vinho',
#   'pra',
#   'variar',
#   'um',
#   'pouco',
#   '!!',
#   'friday',
#   "'s",
#   'celebrate',
#   '!!!',
#   'yupppppp'],
#  ['Friday',
#   'Lunch',
#   'Out',
#   'with',
#   '#Grazildas',
#   '#northpark',
#   '#InstaMagAndroid',
#   '<USR>',
#   'Next',
#   'Door',
#   'Noodles',
#   'North',
#   'Park',
#   'Makati',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'On',
#   'August',
#   '14',
#   ',',
#   'witness',
#   'the',
#   'strength',
#   'of',
#   'street',
#   'knowledge',
#   '.',
#   '#StraightOuttaCompton',
#   '#NWA',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Avian',
#   'influenza',
#   'detected',
#   'on',
#   '3rd',
#   'Oxford',
#   'County',
#   'farm',
#   '<URL>',
#   '|',
#   '<URL>',
#   '<URL>'],
#  ['#inocente2014',
#   'Desde',
#   'que',
#   'ha',
#   'empezado',
#   'la',
#   'gala',
#   'llevo',
#   'viendo',
#   'la',
#   'tele',
#   '!',
#   'Y',
#   'ahora',
#   '<USR>',
#   'con',
#   'Saturday',
#   "I'm",
#   'In',
#   'Love',
#   '!!!!',
#   '<URL>'],
#  ['RT',
#   'storm',
#   '"',
#   'ntlegs11',
#   'Friday',
#   'night',
#   'Nath',
#   '#werunasone',
#   '"',
#   '#purplepride'],
#  ['<USR>', 'Thanks', 'for', 'the', 'follow', 'friday', 'bump', '!', ':)'],
#  ['Son',
#   'popping',
#   'of',
#   'to',
#   'school',
#   ',',
#   'anybody',
#   'want',
#   'a',
#   'shoutout',
#   'before',
#   'i',
#   'go',
#   '?',
#   'just',
#   'ask',
#   ',',
#   'and',
#   'ill',
#   'provide',
#   '.'],
#  ['Economy',
#   'picking',
#   'up',
#   'speed',
#   'as',
#   'latest',
#   'GDP',
#   'figures',
#   'show',
#   'it',
#   'put',
#   'on',
#   '0.7',
#   '%',
#   'growth',
#   'in',
#   'three',
#   'months',
#   'to',
#   'end',
#   'of',
#   'June',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'zayn',
#   'will',
#   'be',
#   'back',
#   'on',
#   'tour',
#   'in',
#   'two',
#   'days',
#   'the',
#   'sun',
#   'is',
#   'coming',
#   'out',
#   'the',
#   'world',
#   'is',
#   'starting',
#   'to',
#   'turn',
#   'and',
#   'im',
#   'finally',
#   'remembering',
#   'my',
#   'name'],
#  ['<USR>',
#   '<USR>',
#   '<USR>',
#   'Great',
#   ',',
#   'I',
#   'will',
#   'be',
#   'there',
#   'tomorrow',
#   'too',
#   '(',
#   'Sue',
#   ')',
#   '...',
#   'look',
#   'forward',
#   'to',
#   'seeing',
#   'you',
#   'at',
#   '10.30',
#   '!'],
#  ['The',
#   'Toyota',
#   'Probox',
#   'was',
#   'introduced',
#   'in',
#   'August',
#   '2002',
#   '.',
#   'It',
#   'is',
#   'a',
#   'small',
#   'station',
#   'wagon',
#   'designed',
#   'for',
#   'commercial',
#   'use',
#   'as',
#   'a',
#   '...',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'This',
#   'morning',
#   "'s",
#   'prediction',
#   'that',
#   'the',
#   '#S',
#   '&amp;',
#   'P',
#   '500',
#   'would',
#   'test',
#   '2,000',
#   'was',
#   'a',
#   'winner',
#   '!',
#   '$SPY',
#   '#China',
#   '$FXI',
#   '--',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   '#GappuKiRani',
#   'Sorry',
#   'they',
#   'r',
#   'Mongolian',
#   'Mules',
#   'not',
#   'horses',
#   '...',
#   'ROFL',
#   '<URL>'],
#  ['Not',
#   'sure',
#   'what',
#   'corner',
#   "they've",
#   'turned',
#   '...',
#   '10th',
#   'seed',
#   'at',
#   'best',
#   '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   'ICYMI',
#   ':',
#   'miss',
#   'A',
#   'said',
#   'to',
#   'be',
#   'preparing',
#   'for',
#   'comeback',
#   'in',
#   'April',
#   '<URL>'],
#  ['RT', '<USR>', ':', 'night', ',', 'see', 'you', 'tomorrow', 'perfffff', '!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Here',
#   "'s",
#   'my',
#   'story',
#   'on',
#   'today',
#   "'s",
#   'Forensic',
#   'Science',
#   'Comm',
#   '.',
#   'meeting',
#   ',',
#   'where',
#   'Willingham',
#   'probe',
#   'took',
#   'a',
#   'remarkable',
#   'turn',
#   '.',
#   '<URL>',
#   '...'],
#  ['Sun', 'Self', 'Tanner', 'A', 'Great', 'Purchase', '<URL>'],
#  ['TOP',
#   'EVENT',
#   '--',
#   '&gt;',
#   '<URL>',
#   '-',
#   'And',
#   'tomorrow',
#   'the',
#   '<USR>',
#   'Event',
#   'goes',
#   'down',
#   '-',
#   'open',
#   'to',
#   'pros',
#   ',',
#   'home',
#   'baristas',
#   ',',
#   'c',
#   '...',
#   '(',
#   'via',
#   '<USR>',
#   ')'],
#  ['Our',
#   'thoughts',
#   'and',
#   'prayers',
#   'go',
#   'out',
#   'to',
#   'all',
#   'of',
#   'those',
#   'affected',
#   'by',
#   'todays',
#   'shooting',
#   'at',
#   'the',
#   'Washington',
#   'Navy',
#   'Yard',
#   '.'],
#  ['Snapchat',
#   ',',
#   'Skype',
#   'hacks',
#   'offer',
#   'security',
#   'lessons',
#   ',',
#   'experts',
#   'say',
#   ':',
#   'The',
#   'Snapchat',
#   'breach',
#   'that',
#   'led',
#   'to',
#   'millions',
#   'of',
#   'user',
#   'n',
#   '...',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   '#13',
#   '-',
#   'Justin',
#   'spotted',
#   'out',
#   'in',
#   'Laguna',
#   'Beach',
#   ',',
#   'California',
#   '-',
#   'August',
#   '8',
#   '#MTVHottest',
#   'Justin',
#   'Bieber',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   '#ZodiacFacts',
#   'As',
#   'an',
#   '#Aries',
#   'romance',
#   'is',
#   "n't",
#   'about',
#   'what',
#   'you',
#   "'re",
#   'after',
#   '--',
#   'it',
#   "'s",
#   'about',
#   'taking',
#   'chances',
#   ',',
#   'exploring',
#   'and',
#   'keeping',
#   'an',
#   '...'],
#  ['Annual',
#   'pancake',
#   'breakfast',
#   'at',
#   'fire',
#   'station',
#   'slated',
#   'for',
#   'October',
#   '3',
#   '<URL>',
#   '#menlopark'],
#  ['Stoked',
#   'about',
#   'the',
#   'awesome',
#   'date',
#   'night',
#   'im',
#   'about',
#   'to',
#   'have',
#   'with',
#   '<USR>',
#   'and',
#   'also',
#   'very',
#   'stoked',
#   'about',
#   'the',
#   'bro',
#   'time',
#   'tomorrow',
#   'with',
#   '<USR>'],
#  ['<URL>', 'January', '08', ',', '2015', 'at', '12:14', 'AM'],
#  ['Apple',
#   'iPod',
#   'touch',
#   '3rd',
#   'Generation',
#   'Black',
#   '(',
#   '64',
#   'GB',
#   ')',
#   'Works',
#   'Great',
#   '-',
#   'Full',
#   'read',
#   'by',
#   'eBay',
#   '<URL>',
#   '<URL>'],
#  ['#Capricorn',
#   'September',
#   '2015',
#   'SUMMER',
#   'SALE',
#   '!',
#   '<URL>',
#   '<URL>',
#   'via',
#   '<USR>'],
#  ['friday', 'night', 'missions', 'iguess', '!'],
#  ['2',
#   'Killed',
#   ',',
#   '7',
#   'Hurt',
#   'in',
#   'Detroit',
#   'Barbershop',
#   'Shooting',
#   '-',
#   'ABC',
#   'News',
#   ':',
#   'New',
#   'York',
#   'Daily',
#   'News2',
#   'Killed',
#   ',',
#   '7',
#   'Hurt',
#   'in',
#   'Detroit',
#   'Bar',
#   '...',
#   '<URL>'],
#  ['<USR>',
#   'Yes',
#   '!',
#   'Was',
#   'so',
#   'great',
#   'to',
#   'walk',
#   'home',
#   'from',
#   'work',
#   'with',
#   'the',
#   'sun',
#   'still',
#   'shining',
#   '.'],
#  ['Stop',
#   'by',
#   'the',
#   'COLLEGE',
#   'REPUBLICAN',
#   'TAILGATE',
#   'tomorrow',
#   '<USR>',
#   '9:30',
#   'in',
#   'Yellow',
#   'Lot',
#   '17',
#   'for',
#   'FOOD',
#   'before',
#   'the',
#   'game'],
#  ['My',
#   'thoughts',
#   '&',
#   'prayers',
#   'go',
#   'out',
#   'to',
#   'the',
#   'family',
#   "'s",
#   'affected',
#   'by',
#   'the',
#   'marysville',
#   'shooting'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Me',
#   'the',
#   'whole',
#   'month',
#   'of',
#   'December',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'TOMORROW',
#   ':',
#   "Don't",
#   'Stop',
#   'The',
#   'Madness',
#   '!',
#   '<USR>',
#   '<USR>',
#   '<URL>'],
#  ['<USR>',
#   'ill',
#   'txt',
#   'you',
#   'soon',
#   'in',
#   'a',
#   'few',
#   'minutes',
#   'when',
#   'i',
#   'get',
#   'a',
#   'hold',
#   'of',
#   'my',
#   'phone'],
#  ['Just',
#   'a',
#   'reminder',
#   'to',
#   'everyone',
#   ',',
#   'Dani',
#   'Pedrosa',
#   'won',
#   'with',
#   'an',
#   'excellent',
#   'ride',
#   'on',
#   'Sunday',
#   '!!',
#   '#MotoGP',
#   '<USR>',
#   '<USR>'],
#  ['<USR>',
#   'can',
#   'u',
#   'please',
#   'follow',
#   'me',
#   '?',
#   'you',
#   'will',
#   'make',
#   'my',
#   'day',
#   '&lt;',
#   '3',
#   '8'],
#  ['1',
#   'dead',
#   ',',
#   '6',
#   'hurt',
#   'in',
#   'Sacramento',
#   'park',
#   'shooting',
#   '<URL>'],
#  ['Personal',
#   'Twitter',
#   'is',
#   'now',
#   'ago',
#   '.',
#   'People',
#   'can',
#   'now',
#   'keep',
#   'track',
#   'of',
#   'me',
#   'instead',
#   'of',
#   'just',
#   'my',
#   'films',
#   'and',
#   'production',
#   'company',
#   '.'],
#  ['<USR>', '2nd', '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Fuck',
#   'I',
#   'hear',
#   'mozzies',
#   'flying',
#   'around',
#   'the',
#   'room',
#   ':(',
#   "I'm",
#   'going',
#   'to',
#   'be',
#   'itchy',
#   'like',
#   'a',
#   'bitchy',
#   'tomorrow',
#   'morning'],
#  ['Here',
#   'is',
#   'a',
#   'little',
#   'taste',
#   'of',
#   'what',
#   'you',
#   'can',
#   'expect',
#   'to',
#   'see',
#   'on',
#   'stage',
#   'at',
#   'the',
#   'Hettinger',
#   '4th',
#   'of',
#   'July',
#   'Celebration',
#   '!',
#   "We're...",
#   '<URL>'],
#  ['Conflicts',
#   'of',
#   'Law',
#   ':',
#   'Cases',
#   'and',
#   'Materials',
#   ':',
#   'R',
#   '.',
#   'Lea',
#   'Brilmayer',
#   ',',
#   'Jack',
#   'L',
#   '.',
#   'Goldsmith[May',
#   '01',
#   ',',
#   '2011',
#   ']',
#   '<URL>'],
#  ['My',
#   'Dec',
#   'tweets',
#   'of',
#   'the',
#   'month',
#   ',',
#   'featuring',
#   'a',
#   'profound',
#   '1',
#   'about',
#   'how',
#   'history',
#   'would',
#   'be',
#   'diff',
#   '.',
#   'if',
#   'Yoko',
#   'had',
#   'fallen',
#   'for',
#   'Moe',
#   '...',
#   '<URL>'],
#  ['It',
#   "'s",
#   'practically',
#   'Christmas',
#   'in',
#   'July',
#   '!',
#   'SEC',
#   'Media',
#   'Days',
#   '2015',
#   '!',
#   '#SECMD15',
#   '#SEC',
#   '<URL>'],
#  ['Amazing',
#   '.',
#   'And',
#   'encouraging',
#   '.',
#   'RT',
#   '<USR>',
#   ':',
#   '36,000',
#   '#bluebutton',
#   'downloads',
#   'for',
#   'VA',
#   'health',
#   'records',
#   'in',
#   '1st',
#   '10',
#   'days',
#   '!'],
#  ['Epic',
#   'Games',
#   'Resets',
#   'Passwords',
#   'Following',
#   'Forum',
#   'Breach',
#   '<URL>'],
#  ['Work',
#   'better',
#   'fly',
#   'by',
#   'tomorrow',
#   'not',
#   'trying',
#   'to',
#   'be',
#   'there'],
#  ['Come',
#   'enjoy',
#   'a',
#   'movie',
#   'in',
#   'our',
#   'romantic',
#   'theater',
#   'room',
#   '.',
#   'January',
#   'is',
#   '25%',
#   'off',
#   'and',
#   'is',
#   'almost',
#   'over',
#   ',',
#   "don't",
#   'miss',
#   'out',
#   '!',
#   'Book',
#   '...',
#   '<URL>'],
#  ['<USR>',
#   'oh',
#   '?',
#   'What',
#   'did',
#   'you',
#   'do',
#   'for',
#   'my',
#   'half',
#   'birthday',
#   ',',
#   '*tomorrow*',
#   '!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'it',
#   "'s",
#   'pointless',
#   'to',
#   'go',
#   'to',
#   'school',
#   'tomorrow',
#   '.'],
#  ['Harvard',
#   'Faculty',
#   'Cry',
#   'Foul',
#   'Over',
#   'Rising',
#   'Obamacare',
#   'Costs',
#   '-',
#   '#Payback',
#   '<URL>',
#   '#TeaParty',
#   '#tcot',
#   '#ObamacareFail'],
#  ['Apple',
#   'iPod',
#   'Touch',
#   '4th',
#   'Generation',
#   'White',
#   '(',
#   '8',
#   'GB',
#   ')',
#   '-',
#   'Bid',
#   'Now',
#   '!',
#   'Only',
#   '$',
#   '41.0',
#   '<URL>',
#   '<URL>'],
#  ['holy',
#   'cow',
#   '-',
#   "I'm",
#   'almost',
#   'ready',
#   'for',
#   'sessions',
#   '!',
#   'Walls',
#   'painted',
#   ',',
#   'lights',
#   'hung',
#   ',',
#   'backdrop',
#   'system',
#   'up',
#   'and',
#   'working',
#   '!',
#   'Tomorrow',
#   '...',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Happy',
#   '18th',
#   'birthday',
#   '<USR>',
#   'sick',
#   'party',
#   '!'],
#  ['RT',
#   '<USR>',
#   ':',
#   '[',
#   'INFO',
#   ']',
#   '#EXID',
#   'to',
#   'perform',
#   'at',
#   'the',
#   'K',
#   'Festival',
#   'at',
#   'Incheon',
#   'Asiad',
#   'Main',
#   'Stadium',
#   'on',
#   'Sept',
#   '.',
#   '11th',
#   '<URL>'],
#  ['RT', '<USR>', ':', '15', 'April', '1994', 'kak', ':)', '<URL>'],
#  ['<USR>',
#   'It',
#   'did',
#   'me',
#   't',
#   'o.I',
#   'was',
#   'so',
#   'sympathtic',
#   'to',
#   'her',
#   'when',
#   'I',
#   'frst',
#   'hrd',
#   'this',
#   '.',
#   'When',
#   'she',
#   'blmd',
#   'a',
#   'AA',
#   'for',
#   'it',
#   'realy',
#   "pis'd",
#   'me',
#   'off',
#   '.',
#   'Someone',
#   'copied',
#   'her',
#   'hoax'],
#  ['Greek', 'Festival', 'at', 'St', 'Johns', 'before', 'ASPEN'],
#  ['#EverydayILoveYouTrailerLaunch',
#   "You're",
#   'my',
#   'sun',
#   ',',
#   'my',
#   'rose',
#   ',',
#   'my',
#   'love',
#   '#PushAwardsLizQuens',
#   'EILYLizQuen',
#   'HeartAndSoul'],
#  ['For',
#   'the',
#   'late',
#   'Friday',
#   'p.m.',
#   'crowd',
#   '{',
#   'all',
#   '3',
#   'of',
#   'you}',
#   '!',
#   'On',
#   'the',
#   'blog',
#   'today',
#   '...',
#   'Creative',
#   'invitation',
#   'wording',
#   'for',
#   'different',
#   'situations',
#   '!',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Well',
#   'losing',
#   'my',
#   'favourite',
#   'sun',
#   'glasses',
#   'in',
#   'Melbourne',
#   'is',
#   'not',
#   'the',
#   'idea',
#   'of',
#   'a',
#   'good',
#   'time',
#   '.',
#   '#Gutted',
#   '#NearlyCried'],
#  ['<USR>', 'korek', 'may', 'sound', 'pa', 'yun', ',', 'hahaha'],
#  ['The', 'Xbox', 'one', 'may', 'be', 'the', 'greatest', 'thing', 'ever'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Good',
#   'to',
#   'see',
#   'others',
#   'protecting',
#   'their',
#   'assets',
#   'too',
#   '#fun',
#   '#Friday',
#   '<URL>'],
#  ['Conversations',
#   'at',
#   'work',
#   'may',
#   'not',
#   'go',
#   'as',
#   'expected',
#   'today',
#   ',',
#   'but',
#   'they',
#   'e',
#   '...',
#   'More',
#   'for',
#   'Cancer',
#   '<URL>'],
#  ['Apple',
#   'Ipod',
#   'A1238',
#   '160GB',
#   '6th',
#   'Gen',
#   'with',
#   'good',
#   'battery',
#   '-',
#   'Full',
#   'read',
#   'by',
#   'eBay',
#   '<URL>',
#   '<URL>'],
#  ['#SanBernardino',
#   'shooting',
#   ':',
#   'At',
#   'least',
#   '14',
#   'people',
#   'killed',
#   ';',
#   '1',
#   'to',
#   '3',
#   'suspects',
#   'on',
#   'loosehttp',
#   ':/',
#   '/',
#   'www.cnn.com/2015/12/02/us/san-bernardino-shooting/index.html',
#   '…'],
#  ['RT',
#   '<USR>',
#   ':',
#   'More',
#   'photos',
#   'of',
#   'JaDine',
#   '.',
#   'On',
#   'The',
#   'Wings',
#   'of',
#   'Love',
#   'will',
#   'air',
#   'August',
#   '10',
#   '.',
#   '#OTWOLMediaDay',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'January',
#   'Sale',
#   'Tassel',
#   'Necklace',
#   '.',
#   'Free',
#   'matching',
#   'by',
#   'JabberDuck',
#   '<URL>',
#   '<URL>'],
#  ['Your',
#   'vivid',
#   'visions',
#   'of',
#   'the',
#   'future',
#   'may',
#   'run',
#   'you',
#   'ragged',
#   'now',
#   ',',
#   'bring',
#   '...',
#   'More',
#   'for',
#   'Pisces',
#   '<URL>'],
#  ['Alcohol',
#   'may',
#   'be',
#   'man',
#   "'s",
#   'woust',
#   'enemy',
#   ',',
#   'but',
#   'xhe',
#   'bible',
#   'says',
#   'love',
#   'your',
#   'enemy',
#   '.'],
#  ['Well',
#   'if',
#   'the',
#   'FBI',
#   'sent',
#   'a',
#   'warning',
#   'then',
#   'I',
#   'guess',
#   "I'm",
#   'not',
#   'going',
#   'to',
#   'class',
#   'tomorrow'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Happy',
#   'Birthday',
#   'sa',
#   'lahat',
# ...
#  ['Saturation', 'Point', '<URL>'],
#  ['<USR>',
#   'imma',
#   'tell',
#   'you',
#   'one',
#   'time',
#   '!',
#   'JUTHTIN',
#   'BEAVERRRR',
#   '!!!!'],
#  ['Need',
#   'someone',
#   'to',
#   'help',
#   'me',
#   'out',
#   'tomorrow',
#   '!!!',
#   'Like',
#   'really',
#   'badly'],
#  ['took',
#   'the',
#   'combine',
#   'out',
#   'for',
#   'a',
#   'spin',
#   'today',
#   ',',
#   'but',
#   'the',
#   'barley',
#   'is',
#   'still',
#   'a',
#   'tad',
#   'on',
#   'the',
#   'wet',
#   'side',
#   '.'],
#  ['VERSEAUUUU',
#   '!',
#   'Ptn',
#   "j'ai",
#   'jamais',
#   'autant',
#   'kiffer',
#   'mon',
#   'signe',
#   'astro',
#   '#ShesKindaHotVMA',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Sunday',
#   'is',
#   'my',
#   'birthday',
#   '.',
#   '82',
#   'years',
#   'young',
#   '!',
#   'What',
#   'should',
#   'I',
#   'wear',
#   '?',
#   '(',
#   "don't",
#   'say',
#   'birthday',
#   'suit',
#   '!',
#   ')'],
#  ['In',
#   '8th',
#   'grade',
#   'we',
#   'had',
#   'a',
#   'debate',
#   'on',
#   'immigration',
#   '.',
#   'It',
#   'was',
#   'not',
#   'even',
#   'a',
#   'debate',
#   'it',
#   'was',
#   'more',
#   'like',
#   'everyone',
#   'yell',
#   'at',
#   'Ashley',
#   'and',
#   'make',
#   'her',
#   'cry',
#   '.'],
#  ['<USR>',
#   'Trying',
#   'to',
#   'access',
#   'account',
#   'since',
#   'the',
#   'security',
#   'breach',
#   '-',
#   'but',
#   'unable',
#   'to',
#   'reset',
#   'password',
#   'since',
#   'acct',
#   'associated',
#   'with',
#   'old',
#   'email',
#   '.',
#   'Help',
#   '?'],
#  ['RT',
#   '<USR>',
#   ':',
#   'HAPPY',
#   'BIRTHDAY',
#   'TO',
#   '<USR>',
#   'WISHIN',
#   'YOU',
#   'THE',
#   'BEST',
#   '&amp;',
#   'HOPE',
#   'YOU',
#   'HAVE',
#   'A',
#   'WONDERFUL',
#   'DAY'],
#  ['Great', '."', '<USR>', ':', '<USR>', '22', 'march', '"'],
#  ['RT', '<USR>', ':', 'Monday', 'morning', 'mood', '<URL>'],
#  ['<USR>',
#   'yeah',
#   '*^*',
#   'it',
#   "'s",
#   'so',
#   'cool',
#   '....',
#   'about',
#   'that',
#   ',',
#   'hopefully',
#   'i',
#   'can',
#   'apply',
#   'for',
#   'a',
#   'credit',
#   'card',
#   'this',
#   'coming',
#   'July'],
#  ['#NOLA',
#   '#NOLAjobs',
#   'Meat',
#   'Department',
#   'Assistant',
#   'Manager',
#   '-',
#   'Metairie',
#   ',',
#   'Louisiana',
#   'Dorignac',
#   "'s",
#   'Food',
#   'Center',
#   'Fri',
#   ',',
#   '11',
#   'Sep',
#   '2015',
#   '18',
#   '...',
#   '<URL>'],
#  ['<USR>',
#   'Have',
#   'fun',
#   ';)',
#   'I',
#   'expect',
#   'updates',
#   'on',
#   'your',
#   'drunk',
#   'status',
#   'since',
#   "I'm",
#   'working',
#   'tonight',
#   '!'],
#  ['<URL>',
#   '…',
#   'Cyber',
#   'security',
#   ':',
#   'Attack',
#   'of',
#   'health',
#   'hackers',
#   '-',
#   'Breach',
#   'of',
#   'Anthem',
#   'database',
#   ',',
#   'probably',
#   'from',
#   'China…',
#   '<URL>'],
#  ['Fuckin',
#   'FRIDAY',
#   'NIGHT',
#   ',',
#   'Tweople',
#   '(',
#   'RIDE',
#   'IT)',
#   '!',
#   '<URL>'],
#  ['The',
#   'new',
#   'day',
#   'is',
#   'waiting',
#   'for',
#   'you',
#   '.',
#   'May',
#   'you',
#   'have',
#   'a',
#   'truly',
#   'wonderful',
#   'time',
#   '<URL>'],
#  ['x1x_Ne_x1x',
#   '<URL>',
#   'September',
#   '23',
#   ',',
#   '2015',
#   'at',
#   '09:45',
#   'AM',
#   '66'],
#  ['I',
#   'hate',
#   'it',
#   'when',
#   'i',
#   'forget',
#   'that',
#   'i',
#   'wear',
#   'glasses&amp;i',
#   'go',
#   'to',
#   'itch',
#   'my',
#   'eye&amp;i',
#   'hit',
#   'my',
#   'glasses',
#   '-_-',
#   '.',
#   'not',
#   'cool'],
#  ['1',
#   'dead',
#   ',',
#   '6',
#   'hurt',
#   'in',
#   'Sacramento',
#   'park',
#   'shooting',
#   '<URL>',
#   'via',
#   '<USR>'],
#  ['Tom',
#   'Stoppard',
#   'to',
#   'be',
#   'honoured',
#   'with',
#   'Pen',
#   "'s",
#   'highest',
#   'accolade',
#   '<URL>',
#   '<USR>'],
#  ['<USR>',
#   'We',
#   'should',
#   "'ve",
#   'scheduled',
#   'a',
#   'meeting',
#   'with',
#   'Trisha',
#   'in',
#   'Paris',
#   'for',
#   'this',
#   'week',
#   '...',
#   '#deau'],
#  ['RT', '<USR>', ':', 'BBQ', 'on', 'Friday', '.'],
#  ['4th',
#   'street',
#   '"',
#   '<USR>',
#   ':',
#   'Uphuzani',
#   '?',
#   'RT',
#   '<USR>',
#   ':',
#   'That',
#   'thing',
#   'gives',
#   'me',
#   'chest',
#   'pains',
#   'hey',
#   '"',
#   'MsGuxx',
#   ':',
#   'A',
#   'guareezy',
#   'would',
#   'be',
#   'lovely',
#   'rn',
#   '""'],
#  ['before',
#   'the',
#   'season',
#   'even',
#   'starts',
#   'i',
#   'will',
#   'not',
#   'respond',
#   'to',
#   'any',
#   'new',
#   'found',
#   'miami',
#   'heat',
#   'fans',
#   '...'],
#  ['Jason',
#   'Industries',
#   'to',
#   'Hold',
#   'Annual',
#   'Meeting',
#   'of',
#   'Stockholders',
#   'on',
#   'May',
#   '20',
#   '<URL>'],
#  ['<USR>',
#   '*purrs',
#   'long',
#   'on',
#   'the',
#   'inside',
#   ',',
#   'moving',
#   'stealthy',
#   'like',
#   'my',
#   'pard',
#   'taught',
#   'me',
#   'to',
#   'do',
#   '..',
#   'ears',
#   'pulled',
#   'back',
#   ',',
#   'claws',
#   'out',
#   'long*',
#   '<USR>'],
#  ['And',
#   'after',
#   'my',
#   'accident',
#   'in',
#   'Feb',
#   ',',
#   'God',
#   'started',
#   'showing',
#   'me',
#   'people',
#   'true',
#   'colors',
#   'and',
#   'weeding',
#   'all',
#   'the',
#   'bs',
#   'out',
#   'my',
#   'life',
#   '...'],
#  ['Gotta',
#   'call',
#   'mom',
#   '2',
#   'let',
#   'her',
#   'know',
#   'it',
#   "'s",
#   'almost',
#   '3',
#   '.',
#   'Yli',
#   'gets',
#   'out',
#   'in',
#   '15',
#   '.',
#   'Mom',
#   'took',
#   'the',
#   'antenna',
#   'home',
#   'today',
#   '&lt;',
#   'connected',
#   'it',
#   'at',
#   'home',
#   ',',
#   'finally',
#   '.'],
#  ['Thinking', 'about', 'Bowlounge', 'on', 'Saturday', 'night', '.'],
#  ['RT',
#   '<USR>',
#   ':',
#   '-Tu',
#   'fais',
#   'quoi',
#   'dans',
#   'la',
#   'vie',
#   '?',
#   '-Je',
#   'fais',
#   'de',
#   'mon',
#   'mieux',
#   '.'],
#  ['Explore',
#   '...',
#   'Dating',
#   'time',
#   'change',
#   'to',
#   '7pm',
#   'on',
#   'Mon',
#   '12/15',
#   '(',
#   'instead',
#   'of',
#   '6',
#   ')',
#   'RT',
#   '!!',
#   '<URL>'],
#  ['ugh',
#   'so',
#   'this',
#   'chick',
#   'onFB',
#   'jus',
#   'wrote',
#   'this',
#   'long',
#   'status',
#   'cussin',
#   'me',
#   'out',
#   ',',
#   'but',
#   'im',
#   'not',
#   'even',
#   'gonna',
#   'stoop',
#   'to',
#   'her',
#   'leve',
#   'but',
#   'i',
#   'wanna',
#   'bomb',
#   'her',
#   'ass',
#   'out',
#   'so',
#   'bad'],
#  ['SATURDAY',
#   'NIGHT',
#   'CAST',
#   'PARTY',
#   'INVITATION',
#   '<URL>',
#   'via',
#   '#constantcontact'],
#  ['Waking',
#   'up',
#   'at',
#   '4am',
#   'for',
#   'a',
#   'day',
#   'trip',
#   'to',
#   'Chicago',
#   'tomorrow',
#   '#PartyHardy',
#   '#SleepierHardier'],
#  ['RT',
#   '<USR>',
#   ':',
#   'HAPPY',
#   'ONE',
#   'MILLION',
#   '!!',
#   'HAPPY',
#   '19th',
#   'WEEKSARY',
#   '!!',
#   '#ALDUB19thWeeksary',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Gravity',
#   'Rush',
#   'Remastered',
#   'coming',
#   'to',
#   'PS4',
#   'on',
#   'February',
#   '9th',
#   ',',
#   '2016',
#   ':',
#   '<URL>',
#   '<URL>'],
#  ['Three',
#   'Major',
#   'News',
#   'Websites',
#   'Hacked',
#   'by',
#   'Syrian',
#   'Electronic',
#   'Army',
#   ':',
#   'A',
#   'serious',
#   'security',
#   'breach',
#   'left',
#   'three',
#   'major',
#   'news',
#   'we',
#   '...',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'My',
#   'cartoon',
#   'Tuesday',
#   '<USR>',
#   'on',
#   '#Greece',
#   "'s",
#   'negotiating',
#   'postion',
#   '#Tsipras',
#   '#Grexit',
#   '<URL>'],
#  ['Selena', 'with', 'fans', 'in', 'NYC', '||', 'May', '3', '#1-4', '<URL>'],
#  ['Costa',
#   'Rica',
#   'generates',
#   'up',
#   'to',
#   '100%',
#   'of',
#   'electricity',
#   'from',
#   'renewables',
#   '.',
#   'Aims',
#   'to',
#   'be',
#   'carbon',
#   'neutral',
#   'by',
#   '2012',
#   '.',
#   '<URL>'],
#  ['Power',
#   'nap',
#   '.',
#   'I',
#   'need',
#   'it',
#   '.',
#   'Its',
#   'been',
#   'a',
#   'stressful',
#   'week',
#   '.',
#   'I',
#   "'m",
#   'excited',
#   'for',
#   'xmas',
#   ',',
#   'haha',
#   '.',
#   'Goodnight',
#   '.',
#   ':)'],
#  ['<USR>',
#   'I',
#   'hate',
#   'it',
#   'here',
#   ',',
#   'lol',
#   '.',
#   "i'm",
#   'moving',
#   'to',
#   'america',
#   'when',
#   "i'm",
#   'at',
#   'least',
#   '23',
#   '.',
#   'no',
#   'joke'],
#  ['<USR>',
#   'Mechanical',
#   'keyboards',
#   'are',
#   'so',
#   'prohibitively',
#   'expensive',
#   'in',
#   'my',
#   '3rd',
#   'world',
#   'shithole',
#   '..',
#   'At',
#   'least',
#   'the',
#   'keyboard',
#   'of',
#   'my',
#   'Thinkpad',
#   "ain't",
#   'bad'],
#  ['<USR>',
#   'not',
#   'yet',
#   ',',
#   'hopefully',
#   'tomorrow',
#   '.',
#   'Faust',
#   'DPS',
#   'check',
#   'is',
#   'serious',
#   'business',
#   'for',
#   'the',
#   'first',
#   '2',
#   'weeks',
#   'probably',
#   'until',
#   'people',
#   'get',
#   'il200',
#   'weapon',
#   '.'],
#  ['I',
#   '#VoteTrisMTV',
#   'for',
#   'Best',
#   'Hero',
#   '!',
#   'Watch',
#   'the',
#   'MTV',
#   'on',
#   'April',
#   '12',
#   'starting',
#   'at',
#   '7:30',
#   'ET',
#   'to',
#   'see',
#   'who',
#   'wins',
#   '!',
#   '89'],
#  ['<USR>',
#   'love',
#   'to',
#   ',',
#   'it',
#   "'s",
#   'iffy',
#   'though',
#   ',',
#   'i',
#   "don't",
#   'wanna',
#   'give',
#   'up',
#   'privacy',
#   'for',
#   'the',
#   'guys',
#   '.',
#   'But',
#   'after',
#   'episode',
#   'one',
#   ',',
#   'they',
#   'should',
#   'be',
#   'on',
#   'imdb',
#   ';)'],
#  ['#Colocation',
#   'European',
#   'data',
#   'centre',
#   'services',
#   'provider',
#   'Interxion',
#   'suffers',
#   'breach',
#   ':',
#   'A',
#   'vulnerability',
#   'present',
#   'in',
#   'the',
#   'cu',
#   '...',
#   '<URL>'],
#  ['MKS',
#   'Instruments',
#   'to',
#   'Participate',
#   'in',
#   '7th',
#   'Annual',
#   'CEO',
#   'Investor',
#   'Summit',
#   '2015',
#   '<URL>'],
#  ['#PushAwardsLizQuens', '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   '<USR>',
#   'Apne',
#   'desh',
#   'may',
#   'Chup',
#   'Chup',
#   'ka',
#   'boltay',
#   'ho',
#   ',',
#   'Videsh',
#   'may',
#   'khulay',
#   'aam',
#   'Jooth',
#   'bolte',
#   'ho',
#   '.',
#   'Sharam',
#   'karo',
#   'Feku',
#   'ji',
#   '!'],
#  ['So',
#   'far',
#   'this',
#   'day',
#   'hasn&apos;',
#   ';',
#   't',
#   'gone',
#   'to',
#   'well',
#   ',',
#   'hopefully',
#   'my',
#   'night',
#   'will',
#   'be',
#   'better',
#   '!'],
#  ['RT', '<USR>', ':', 'Richard', 'may', 'need', 'some', 'help', '.', '<URL>'],
#  ['Today',
#   "'s",
#   'cheer',
#   'went',
#   'from',
#   'awful',
#   'to',
#   'awesome',
#   'from',
#   'the',
#   'moment',
#   'I',
#   'realized',
#   'I',
#   'did',
#   'not',
#   'have',
#   'class',
#   'today',
#   '.'],
#  ['Season', 'opener', 'for', 'Bradley', 'Soccer', 'tonight', '!'],
#  ['New',
#   'artwork',
#   'for',
#   'sale',
#   '!',
#   '-',
#   '"',
#   'Saturday',
#   'Night',
#   'Live',
#   'in',
#   'Beantown',
#   '"',
#   '-',
#   '<URL>'],
#  ['<URL>', 'July', '23', ',', '2015', 'at', '03:19', 'AM'],
#  ['RT',
#   '<USR>',
#   ':',
#   'FYI',
#   '!',
#   'Tomorrow',
#   'is',
#   '<USR>',
#   'pledge',
#   'day',
#   '!',
#   '<URL>',
#   '<URL>'],
#  ['Let',
#   "'s",
#   'Vote',
#   '!',
#   '#KCA',
#   '#VoteJKT48ID',
#   'April',
#   '11',
#   ',',
#   '2015',
#   'at',
#   '04:21',
#   'AM'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Happy',
#   '43rd',
#   'birthday',
#   'to',
#   'former',
#   'Manchester',
#   'United',
#   'player',
#   ',',
#   'Jaap',
#   'Stam',
#   '(',
#   '17th',
#   'July',
#   '1972)',
#   '.',
#   '#mufc',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'TVD',
#   'went',
#   'up',
#   'with',
#   '1.80',
#   'M',
#   'viewers',
#   'YAY',
#   '<URL>',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'From',
#   '3rd',
#   'place',
#   'w/',
#   '20k',
#   'behind',
#   'to',
#   '1st',
#   'with',
#   'almost',
#   '30k',
#   'leading',
#   ',',
#   'fantastic',
#   '!',
#   '#VoteKatnissMTV',
#   '<URL>'],
#  ['Savour',
#   'all',
#   'the',
#   'little',
#   'moments',
#   'in',
#   'the',
#   'here',
#   'and',
#   'now',
#   ',',
#   "we're",
#   'never',
#   'guaranteed',
#   'tomorrow',
#   '.'],
#  ['I',
#   'REMEMBER',
#   'WHEN',
#   'ME',
#   'AND',
#   'KYLIE',
#   'WERE',
#   'OBSESSED',
#   'WITH',
#   'THIS',
#   'SONG',
#   'IN',
#   'THE',
#   '7TH',
#   'GRADE',
#   '5',
#   'YEARS',
#   'AGO',
#   '<URL>'],
#  ['Every',
#   'Saturday',
#   'night',
#   'Casitas',
#   'presents',
#   'Luna',
#   'Lounge',
#   ',',
#   'the',
#   'perfect',
#   'setting',
#   'to',
#   'linger',
#   'under',
#   'the',
#   'moonlight',
#   '<URL>'],
#  ['changed',
#   'mii',
#   'twitta',
#   'name',
#   'i',
#   'wass',
#   'really',
#   'on',
#   'mii',
#   'nerd',
#   'floww',
#   'todaii',
#   'them',
#   'glasses',
#   'are',
#   'the',
#   'best',
#   '......',
#   'nerd',
#   'glasses',
#   'on',
#   'deck',
#   '...',
#   'now',
#   'time',
#   'for',
#   'church'],
#  ['February', 'jobs', 'report', '...', '<URL>'],
#  ['<USR>',
#   '<USR>',
#   'Well',
#   '.',
#   'just',
#   'beg',
#   '<USR>',
#   '..',
#   'PLEASE',
#   'come',
#   'to',
#   'the',
#   '#SBLeurope',
#   'Next',
#   'year',
#   '!.',
#   'We',
#   'need',
#   'you',
#   'there',
#   '!',
#   '*puss',
#   'in',
#   'boots',
#   'eyes*'],
#  ['Will',
#   'Friday',
#   "'s",
#   'Movie',
#   'in',
#   'the',
#   'Park',
#   'be',
#   'ever',
#   'in',
#   'your',
#   'favor',
#   '?',
#   '[',
#   'BLOG',
#   ']',
#   '<URL>',
#   '#Aggieland'],
#  ['Saturday',
#   'September',
#   '18th',
#   '2010',
#   '8pm',
#   'Hotel',
#   'Elegante',
#   'Steve',
#   '&quot;',
#   'Stylez',
#   '&quot;',
#   'A.K.A.',
#   'Desperado',
#   'Birthday',
#   'Bash',
#   '!',
#   '&quot;',
#   'Headrush',
#   'in',
#   'da',
#   'building',
#   '&quot;'],
#  ['#fusillade', '#college', '#californie', '#nouvelles', '<URL>', '…'],
#  ['Sunday',
#   'mornings',
#   'always',
#   'consist',
#   'of',
#   'football',
#   'league',
#   'show',
#   'on',
#   'x20',
#   'until',
#   'Sheff',
#   'Wednesday',
#   'come',
#   'on'],
#  ['Sa', 'love', 'parang', 'Nokia', '3310', 'palaging', 'may', 'snake', '.'],
#  ['<USR>',
#   'Looking',
#   'for',
#   'coffee',
#   'shop/stall',
#   'to',
#   'set',
#   'up',
#   'at',
#   'school',
#   'fair',
#   'in',
#   'Finchley',
#   ',',
#   'London',
#   'N3',
#   'in',
#   'June',
#   '-',
#   'can',
#   'you',
#   'help',
#   'at',
#   'all',
#   '?'],
#  ['Patreon', 'security', 'breach', '<URL>', '…'],
#  ['“@HuffingtonPost',
#   ':',
#   '#Chattanooga',
#   'shooting',
#   'suspect',
#   'identified',
#   'as',
#   'Muhammad',
#   'Youssef',
#   'Abdulazeez',
#   '<URL>',
#   '”ummm'],
#  ['<USR>',
#   'DO',
#   'IT',
#   '!',
#   'it',
#   "'s",
#   'better',
#   'with',
#   'dirty',
#   'hair',
#   'too',
#   '.',
#   'when',
#   'my',
#   'hair',
#   'is',
#   'too',
#   'clean',
#   'it',
#   "'s",
#   'nearly',
#   'impossible',
#   'to',
#   'do',
#   'nything',
#   'w',
#   'it',
#   '!!!'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Good',
#   'thing',
#   "I'm",
#   'watching',
#   'alone',
#   '!',
#   'Lol',
#   '.',
#   '#AlDubWeBelongTogether',
#   '<URL>'],
#  ['sfitzy93',
#   'asked',
#   ':',
#   'No',
#   'problem',
#   '(',
#   ':',
#   'awesome',
#   '!',
#   'toast',
#   '=',
#   'life',
#   ':P',
#   '..',
#   'You',
#   'doing',
#   'anything',
#   'for',
#   'the',
#   'day',
#   '?',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Miley',
#   'Cyrus',
#   'at',
#   'the',
#   'Cosmopolitan',
#   'launch',
#   'party',
#   'in',
#   'New',
#   'York',
#   'on',
#   'february',
#   '13th',
#   ',',
#   '2013',
#   '<URL>'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Syria',
#   "'s",
#   'Assad',
#   'held',
#   'talks',
#   'with',
#   'Putin',
#   'in',
#   'Moscow',
#   'on',
#   'Tuesday',
#   'on',
#   'unannounced',
#   'visit',
#   '-',
#   'Kremlim',
#   '<URL>'],
#  ['I',
#   '#VoteTrisMTV',
#   'for',
#   'Best',
#   'Hero',
#   '!',
#   'Watch',
#   'th',
#   'e',
#   '<USR>',
#   '#movieawards',
#   'on',
#   'April',
#   '12',
#   'starting',
#   'at',
#   '7:30',
#   'ET',
#   'to',
#   'see',
#   'who',
#   'wins',
#   '!',
#   '<URL>'],
#  ['July',
#   '13',
#   ',',
#   '2015',
#   'at',
#   '05:20',
#   'PM',
#   '2015-07-13T',
#   '10:20',
#   ':',
#   '27+',
#   '02:00',
#   '0'],
#  ['must',
#   'be',
#   'a',
#   'slow',
#   'news',
#   'day',
#   'for',
#   'everybody',
#   '2',
#   'b',
#   'talkin',
#   'bout',
#   'a',
#   'known',
#   'druggie/acoholic',
#   'bi',
#   'actress',
#   'testin',
#   'pos',
#   '.',
#   'for',
#   'caine'],
#  ['#bbcaq',
#   'Sun',
#   'always',
#   'shines',
#   'for',
#   '#Photoactive',
#   'cells',
#   '.',
#   'The',
#   'tide',
#   'always',
#   'rises',
#   '&amp;',
#   'falls',
#   '.',
#   'The',
#   'waves',
#   'always',
#   'swell',
#   '&amp;',
#   'roll',
#   '...',
#   '#SustainableEnergy'],
#  ['SBM',
#   '401SO',
#   'Battery=48%',
#   ',',
#   'Status',
#   '=d',
#   'ischarging',
#   'Dec',
#   '13',
#   ',',
#   '2015',
#   '7:00',
#   ':',
#   '54',
#   'PM',
#   '#tweetbatt'],
#  ['SCOTT',
#   'WEILAND',
#   'Announces',
#   'Memoir',
#   'Release',
#   '-',
#   'Music',
#   'News',
#   'Net',
#   ':',
#   'MUSIC',
#   'NEWS',
#   '-',
#   'Simon',
#   '&amp;',
#   'Schuster',
#   'has',
#   'announced',
#   'a',
#   'March',
#   '8',
#   ',',
#   '20',
#   '...',
#   '<URL>'],
#  ['<USR>', '<URL>', 'January', '15', ',', '2015', 'at', '06:16', 'AM'],
#  ['RT',
#   '<USR>',
#   ':',
#   'Dieci',
#   'migranti',
#   'sono',
#   'annegati',
#   'nel',
#   'mar',
#   'Egeo',
#   '.',
#   'Cinque',
#   'erano',
#   'bambini',
#   '.',
#   '<URL>'],
#  ['tomorow', 'on', 'day', 'off', '!!', 'youppppiiieeee'],
#  ['2',
#   'dead',
#   ',',
#   '2',
#   'wounded',
#   'after',
#   'shooting',
#   'at',
#   'Al',
#   'Barnes',
#   'Park',
#   'in',
#   'Tampa',
#   '-',
#   '<USR>',
#   '<URL>'],
#  ['Not',
#   'sure',
#   'if',
#   'I',
#   'want',
#   'to',
#   'cam',
#   'tonight',
#   'or',
#   'tomorrow',
#   '...',
#   'What',
#   'do',
#   'you',
#   'guys',
#   'think',
#   '?',
#   '<URL>',
#   '<URL>'],
#  ['Poetry',
#   'Sunday',
#   ':',
#   "'",
#   'Fox',
#   'Woman',
#   ",'",
#   'by',
#   'Dorothy',
#   'Gilbert',
#   '|',
#   'Women',
#   "'s",
#   'Voices',
#   'For',
#   'Change',
#   '<URL>',
#   'via',
#   '<USR>'],
#  ['#plan',
#   'Land',
#   'of',
#   'Talk',
#   '-',
#   'Minneapolis',
#   '(',
#   'First',
#   'Avenue',
#   'and',
#   '7th',
#   'St',
#   'Entry',
#   ')',
#   'Wed',
#   ',',
#   'Sep',
#   '29',
#   ',',
#   '2010',
#   '<URL>'],
#  ...]

# %% [markdown]
# Всегда полезно знать, с какими данными вы работаете. Выведем небольшую часть.

# %%
for i in range(3):
    for token, one_tag in zip(train_sentences[i], train_tags[i]):
        print('%s\t%s' % (token, one_tag))
    print()
# Out:
# RT	O
# <USR>	O
# :	O
# Online	O
# ticket	O
# sales	O
# for	O
# Ghostland	B-musicartist
# Observatory	I-musicartist
# extended	O
# until	O
# 6	O
# PM	O
# EST	O
# due	O
# to	O
# high	O
# demand	O
# .	O
# Get	O
# them	O
# before	O
# they	O
# sell	O
# out	O
# ...	O
#
# Apple	B-product
# MacBook	I-product
# Pro	I-product
# A1278	I-product
# 13.3	I-product
# "	I-product
# Laptop	I-product
# -	I-product
# MD101LL/A	I-product
# (	O
# June	O
# ,	O
# 2012	O
# )	O
# -	O
# Full	O
# read	O
# by	O
# eBay	B-company
# <URL>	O
# <URL>	O
#
# Happy	O
# Birthday	O
# <USR>	O
# !	O
# May	O
# Allah	B-person
# s.w.t	O
# bless	O
# you	O
# with	O
# goodness	O
# and	O
# happiness	O
# .	O

# %% [markdown]
# ### Подготовка словарей
#
# Чтобы обучать нейронную сеть, мы будем использовать два отображения.
#
# - {token}$\to${token id}: устанавливает соответствие между токеном и строкой в embedding матрице;
# - {tag}$\to${tag id}: one hot encoding тегов.
#
#
# Теперь вам необходимо реализовать функцию *build_dict*, которая должна возвращать словарь {token or tag}$\to${index} и контейнер, задающий обратное отображение.
#
# **<font color='red'>Задание. Реализуйте функцию build_dict.</font>**

# %%
def build_dict(entities, special_entities):
    """
    Args:
        entities: a list of lists of tokens or tags
        special_entities: some special tokens
        
    Returns:
        entity_to_idx : mapping to index  
        idx_to_entity : mapping from index
    """
    entity_to_idx = dict()
    idx_to_entity = []
    
    # Create mappings from tokens to indices and vice versa
    # Add special tokens to dictionaries
    # The first special token must have index 0

    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    
    entities_flat = []
    for sublist in entities:
        for item in sublist:
            entities_flat.append(item)
    
    for idx in range(len(special_entities)):
        token = special_entities[idx]
        entity_to_idx[token] = idx
        idx_to_entity.append(token)
        
    for idx, token in zip(range(len(entities_flat)), set(entities_flat) - set(special_entities)):
        entity_to_idx[token] = idx 
        idx_to_entity.append(token)
      
    return entity_to_idx, idx_to_entity

# %% [markdown]
# После реализации функции *build_dict* вы можете создать словари для токенов и тегов. В нашем случае специальными токенами будут:
#  - `<UNK>` токен для обозначаения слов, которых нет в словаре;
#  - `<PAD>` токен для дополнения предложений одного батча до одинаковой длины.

# %%
special_tokens = ['<UNK>', '<PAD>']
special_tags = []

# Create dictionaries 
token_to_idx, idx_to_token = build_dict(train_sentences + val_sentences, special_tokens)
tag_to_idx, idx_to_tag = build_dict(train_tags, special_tags)

# %% [markdown]
# ### Подготовка датасета и загрузчика
#
# Обычно нейронные сети обучаются батчами. Это означает, что каждое обновление весов нейронной сети происходит на основе нескольких последовательностей. Технической деталью является необходимость дополнить все последовательности внутри батча до одной длины.
#
# Для начала необходимо реализовать <<датасет>> для хранения ваших данных. Датасет должен наследоваться от стандартного pytorch класса `Dataset` и переопределять методы `__getitem__` и `__len__`. Метод `__getitem__` должен возвращать индексированную последовательность и её теги. Не забудьте про `<UNK>` токен для неизвестных слов!
#
# **<font color='red'>Задание. Реализуйте класс TaggingDataset.</font>**

# %%
from torch.utils.data import Dataset, DataLoader


class TaggingDataset(Dataset):
    special_token = '<UNK>'
    def __init__(self, sentences, tags, token_to_idx, tag_to_idx):
        """
        Args:
            sentences: a list of lists of tokens or tags
            tags: some special tokens
            token_to_idx: mapping from token to token indexes
            tag_to_idx: mapping from tag to tag indexes
        """
        super().__init__()
        ######################################
        ######### YOUR CODE HERE #############
        ######################################
        
        self.sentences = sentences
        self.tags = tags
        self.token_to_idx = token_to_idx
        self.tag_to_idx = tag_to_idx
        
    def __getitem__(self, idx):
        """
        Args:
            idx : int
            
        Returns:
            sentence_idx : torch.tensor of token indexes
            tag_idx : torch.tensor of tag indexes
        """
        ######################################
        ######### YOUR CODE HERE #############
        ######################################
    
        sentence = self.sentences[idx]
        sentence_idx = torch.tensor([self.token_to_idx.get(item, token_to_idx[self.special_token]) for item in sentence])
        
        tag = self.tags[idx]
        tag_idx = torch.tensor([self.tag_to_idx.get(item) for item in tag])
        
        return sentence_idx, tag_idx
    
    def __len__(self):
        ######################################
        ######### YOUR CODE HERE #############
        ######################################
        
        return len(self.sentences)

# %% [markdown]
# Для того, чтобы дополнять последовательности паддингом, будем использовать параметр `collate_fn` класса `DataLoader`. Принимая последовательность пар тензоров для предложений и тегов, необходимо дополнить все последовательности до последовательности максимальной длины в батче. Используйте специальные теги `<PAD>` и `O` для дополнения.
#
# **<font color='red'>Задание. Реализуйте класс PaddingCollator.</font>**

# %%
from torch.nn.utils.rnn import pad_sequence


class PaddingCollator:
    special_token = ['<PAD>', 'O']
    def __init__(self,  pad_token_id, pad_tag_id, batch_first=True):
        self.pad_token_id = pad_token_id
        self.pad_tag_id = pad_tag_id
        self.batch_first = batch_first
        
    def __call__(self, batch):
        """
        Args:
            batch: list of tuples of torch.tensors
        
        Returns:
            new_sentences: torch.tensor
            new_tags: torch.tensor
                Both tensors have the same size 
        """
        ######################################
        ######### YOUR CODE HERE #############
        ######################################
        
        max_length = 0
        for element in batch:
            if max_length < len(element[0]):
                max_length = len(element[0])
        
        new_sentences = list(range(len(batch)))
        new_tags = list(range(len(batch)))
        
        for i, (sentence, tag) in zip(range(len(new_sentences)), batch):
            sent_len_dif = max_length - len(sentence)
            add_sentence = torch.tensor([self.pad_token_id] * sent_len_dif, dtype = torch.long)
            
            if self.batch_first:
                sentence = torch.cat([sentence, add_sentence])
            else:
                sentence = torch.cat([add_sentence, sentence])
            new_sentences[i] = sentence
            
        for j, (sentence, tag) in zip(range(len(new_tags)), batch):
            
            tag_len_dif = max_length - len(tag)
            add_tag = torch.tensor([self.pad_tag_id] * tag_len_dif, dtype = torch.long)
            
            if self.batch_first:
                tag = torch.cat([tag, add_tag])
            else:
                tag = torch.cat([add_tag, tag])
            new_tags[j] = tag
            
        return torch.cat(new_sentences).reshape(len(batch), -1), torch.cat(new_tags).reshape(len(batch), -1)

# %% [markdown]
# Теперь всё готово, чтобы задать DataLoader. Протестируйте на примере ниже, что всё работает правильно.

# %%
small_dataset = TaggingDataset(
    sentences=train_sentences[:7],
    tags=train_tags[:7],
    token_to_idx=token_to_idx,
    tag_to_idx=tag_to_idx,
)

small_loader = DataLoader(
    small_dataset,
    batch_size=3,
    shuffle=False,
    drop_last=False,
    collate_fn=PaddingCollator(
        pad_token_id=token_to_idx['<PAD>'],
        pad_tag_id=tag_to_idx['O'],
        batch_first=True,
    ),
)

batch_lengths = [3, 3, 1]
sequence_lengths = [26, 25, 8]
some_pad_tensor = torch.LongTensor([token_to_idx['<PAD>']] * 12)
some_outside_tensor = torch.LongTensor([[tag_to_idx['O']] * 12])

for i, (tokens_batch, tags_batch) in enumerate(small_loader):
    assert tokens_batch.dtype == torch.int64, 'tokens_batch is not LongTensor'
    assert tags_batch.dtype == torch.int64, 'tags_batch is not LongTensor'
    
    assert len(tokens_batch) == batch_lengths[i], 'wrong batch length'
    
    for one_token_sequence in tokens_batch:
        assert len(one_token_sequence) == sequence_lengths[i], 'wrong length of sequence in batch'
    
    if i == 0:
        assert torch.all(tokens_batch[2][-12:] == some_pad_tensor), "wrong padding"       
        assert torch.all(tags_batch[2][-12:] == some_outside_tensor), "wrong O tag"

# %% [markdown]
# **<font color='red'>Задание. В ячейке ниже задайте датасеты и загрузчики для обучающих, валидационных и тестовых данных.</font>**

# %%
######################################
######### YOUR CODE HERE #############
######################################
train_data = TaggingDataset(train_sentences, train_tags, token_to_idx, tag_to_idx)
validation_data = TaggingDataset(val_sentences, val_tags, token_to_idx, tag_to_idx)
test_data = TaggingDataset(test_sentences, test_tags, token_to_idx, tag_to_idx)


train_loader = DataLoader(dataset = train_data, batch_size = 128, shuffle = True,
    collate_fn = PaddingCollator(batch_first = True, pad_token_id = token_to_idx['<PAD>'], pad_tag_id = tag_to_idx['O']))
validation_loader = DataLoader(dataset = validation_data, batch_size = 64, shuffle = False,
    collate_fn = PaddingCollator(batch_first = True, pad_token_id = token_to_idx['<PAD>'], pad_tag_id = tag_to_idx['O']))
test_loader = DataLoader(dataset = test_data, batch_size = 724, shuffle = False,
    collate_fn = PaddingCollator(batch_first = True, pad_token_id = token_to_idx['<PAD>'], pad_tag_id = tag_to_idx['O']))

# %% [markdown]
# ## Часть 2. BiLSTM-теггер (4 балла)
#
# Определите архитектуру сети, используя библиотеку pytorch.
#
# Ваша архитектура в этом пункте должна соответствовать стандартному теггеру (см. лекцию):
# * Embedding слой на входе
# * Двунаправленный LSTM слой для обработки последовательности
# * Используйте dropout (заданный отдельно или встроенный в LSTM) для уменьшения переобучения
# * Linear слой на выходе
#
# Для обучения сети используйте поэлементную кросс-энтропийную функцию потерь.
# **Обратите внимание**, что `<PAD>` токены не должны учавствовать в подсчёте функции потерь. В качестве оптимизатора рекомендуется использовать Adam. Для получения значений предсказаний по выходам модели используйте функцию $\arg\max$.
#
# **<font color='red'>Задание. Задайте архитектуру сети и требуемые методы.</font>**

# %%
class BiLSTMModel(torch.nn.Module):
    def __init__(
        self,
        vocabulary_size,
        tag_space_size,
        pad_token_idx,
        embedding_dim,
        lstm_hidden_size,
        dropout_zeroed_probability,
        device='cpu'
    ):
        '''
        Defines neural network structure.
        
        architecture: input -> Embedding -> BiLSTM with Dropout -> Linear
        
        ----------
        Parameters
        
        vocabulary_size: int, number of words in vocabulary.
        tag_space_size: int, number of tags.
        pad_token_idx: int, index of padding character. Used for loss masking.
        embedding_dim: int, dimension of words' embeddings.
        lstm_hidden_size: int, number of hidden units in each LSTM cell
        dropout_zeroed_probability: float, dropout zeroed probability for Dropout layer.
        device: str, cpu or cuda:x
        '''
        ######################################
        ######### YOUR CODE HERE #############
        ######################################        
        
        super(BiLSTMModel, self).__init__()
        self.vocabulary_size = vocabulary_size
        self.tag_space_size = tag_space_size
        self.pad_token_idx = pad_token_idx
        self.embedding_dim = embedding_dim
        self.lstm_hidden_size = lstm_hidden_size
        self.dropout_zeroed_probability = dropout_zeroed_probability
        self.device = device
        
        self.embeddings = nn.Embedding(vocabulary_size, embedding_dim, padding_idx = self.pad_token_idx)
        
        self.bilstm = nn.LSTM(self.embedding_dim, self.lstm_hidden_size, num_layers=1, dropout=self.dropout_zeroed_probability, 
            bidirectional=True)
        self.hidden2label1 = nn.Linear(self.lstm_hidden_size*2, self.lstm_hidden_size)
        self.hidden2label2 = nn.Linear(self.lstm_hidden_size, self.tag_space_size)
        self.dropout = nn.Dropout(self.dropout_zeroed_probability)
        
    def forward(self, x_batch): #x
        '''
        Makes forward pass.
        
        ----------
        Parameters
        x_batch: torch.LongTensor with shape (number of samples in batch, number words in sentence).
        '''
        ######################################
        ######### YOUR CODE HERE #############
        ######################################        
        
        x_batch = x_batch.to(device)
        x_batch_emb = self.embeddings(x_batch).to(device)
        
        x_batch = x_batch_emb.view(-1, len(x_batch), embed.size(1))
        bilstm_out, _ = self.bilstm(x_batch)
        
        bilstm_out = torch.transpose(bilstm_out, 0, 1)
        bilstm_out = torch.transpose(bilstm_out, 1, 2)
        bilstm_out = nn.functional.tanh(bilstm_out)
        bilstm_out = nn.functional.max_pool1d(bilstm_out, bilstm_out.size(2)).squeeze(2)
        y = self.hidden2label1(bilstm_out)
        y = self.hidden2label2(y)
        return y
    
    def predict_for_batch(self, x_batch):
        '''
        Returns predictions for x_batch. Use argmax function.
        
        return type: torch.LongTensor
        return shape: (number of samples in batch, number words in sentence.
        
        ----------
        Parameters
        x_batch: torch.LongTensor with shape (number of samples in batch, number words in sentence).
        '''
        ######################################
        ######### YOUR CODE HERE #############
        ######################################
        
        predict_list = []
        
        for item in x_batch:
            predicted = model(item)
            tags = predicted.data.max(1)[1]
            predict_list += [tag for tag in tags]
        return predict_list

# %% [markdown]
# Для тестирования сети мы подготовили для вас класс ScoreEvaluator с двумя полезными методами:
#  - *predict_tags*: получает батч данных и трансформирует его в список из токенов и предсказанных тегов;
#  - *eval_conll*: вычисляет метрики precision, recall и F1

# %%
from evaluation_ner import ScoreEvaluator

evaluator = ScoreEvaluator(
    token_to_idx=token_to_idx,
    idx_to_tag=idx_to_tag,
    idx_to_token=idx_to_token,
)

# %% [markdown]
# ### Эксперименты
#
# Задайте BiLSTMModel. Рекомендуем начать с параметров:
# - *batch_size*: 32;
# - начальное значение *learning_rate*: 0.01-0.001
# - *dropout_zeroed_probability*: 0.5-0.7
# - *embedding_dim*: 100-200
# - *lstm_hidden_size*: 150-200

# %% [markdown]
# Проведите эксперименты на данных. Настраивайте параметры по валидационной выборке, не используя тестовую. Ваше цель — настроить сеть так, чтобы качество модели по F1 мере на валидационной и тестовой выборках было не меньше 0.35. При некотором усердии, можно достичь результата 0.45 по F1 на обоих датасетах.
#
# Если сеть плохо обучается, попробуйте использовать следующие модификации:
#     * используйте gradient clipping
#     * ограничивайте норму эмбеддингов через параметр max_norm (сопоставляйте с значениями в клиппинге)
#     * на каждой итерации уменьшайте learning rate (например, в 1.1 раз)
#     * попробуйте вместо Adam другие оптимизаторы
#     * используйте l2 регуляризацию
#     * экспериментируйте с значением dropout
#
# Сделайте выводы о качестве модели, переобучении, чувствительности архитектуры к выбору гиперпараметров. Оформите результаты экспериментов в виде мини-отчета (в этом же ipython notebook).
#
# **<font color='red'>Задание. Проведите требуемые эксперименты.</font>**

# %%
######################################
######### YOUR CODE HERE #############
######################################

batch_size = 32
learning_rate = 0.001
dropout_zeroed_probability = 0.5
embedding_dim = 100
lstm_hidden_size = 200

vocabulary_size = len(token_to_idx)
tag_space_size = len(tag_to_idx)
pad_token_idx = 1
pad_token_id = token_to_idx['<PAD>']
device = 'cpu'

# %%
model = BiLSTMModel(vocabulary_size, tag_space_size, pad_token_idx, embedding_dim, lstm_hidden_size, dropout_zeroed_probability)
model = model.to(device)

loss = nn.CrossEntropyLoss(ignore_index = pad_token_id).to(device)
optimizer = optim.Adam(model.parameters(), lr = learning_rate)
# Out:
# D:\Anaconda\lib\site-packages\torch\nn\modules\rnn.py:50: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
train_idxs = []
train_tag_idxs = []
for idx in range(len(train_tags)):
    train_idxs.append([token_to_idx[i] for i in train_sentences[idx]])
    train_tag_idxs.append([tag_to_idx[j] for j in train_tags[idx]])

# %%
test_idxs = []
test_tag_idxs = []
for idx in range(len(test_tags)):
    test_idxs.append([token_to_idx[i] for i in test_sentences[idx]])
    test_tag_idxs.append([tag_to_idx[j] for j in test_tags[idx]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-0cdfcfb68a54> in <module>
#       2 test_tag_idxs = []
#       3 for idx in range(len(test_tags)):
# ----> 4     test_idxs.append([token_to_idx[i] for i in test_sentences[idx]])
#       5     test_tag_idxs.append([tag_to_idx[j] for j in test_tags[idx]])
#
# <ipython-input-18-0cdfcfb68a54> in <listcomp>(.0)
#       2 test_tag_idxs = []
#       3 for idx in range(len(test_tags)):
# ----> 4     test_idxs.append([token_to_idx[i] for i in test_sentences[idx]])
#       5     test_tag_idxs.append([tag_to_idx[j] for j in test_tags[idx]])
#
# KeyError: 'carry'

# %%
token_to_idx['carry']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-1be181e4e580> in <module>
# ----> 1 token_to_idx['carry']
#
# KeyError: 'carry'

# %%
ScoreEvaluator(model, train_loader, idx_to_token = idx_to_token)

# %% [markdown]
# ## Необучаемый пост-процессинг результата (4 балла).
#
# Для обучения нейросетевой модели разметки используется поэлементная кросс-энтропия. При использовании на этапе инференса функции $\arg \max$ для получения выходной последовательности, мы не можем гарантировать согласованность предсказаний. Для согласованности необходимо вместо $\arg \max$ использовать другие функции получения предсказаний.
#
# В модели CRF для получения предсказаний используется алгоритм Витерби. Напомним, что модель CRF моделирует вероятность последовательности $y$ при условии $x$ линейной моделью с вектором весов $w \in \mathbb{R}^d$, которая после некоторых преобразований записывается следующим образом:
# $$
# p(y|x, w) = \frac{1}{Z(x, w)} \exp\left( \sum_{i=1}^n \sum_{j = 1}^d w_j f_j(y_{i-1}, y_i, x_i, i) \right) =  \frac{1}{Z(x, w)} \exp\left( \sum_{i=1}^n G_{x, i}[y_{i-1}, y_i] \right)
# $$
#
# Модель необучаемого пост-процессинга **подробно описана** в приложении к заданию. Она сводится к следующим шагам.
#
# 1. Реализовать модель CRF с двумя признаками:
#
#     * Лог-софтмакс выходов модели (выход, соответствующий $y_i$ тэгу для i-го токена будем обозначать $S_{i,y_i}$)
#
#     $$
#     f_1(y_{i-1}, y_i, x_i, i) = S_{i,y_i}
#     $$
#
#     * Логарифмы вероятностей переходов
#
#     $$
#     f_2(y_{i-1}, y_i, x_i, i) = \log A[v=y_{i}, u=y_{i-1}] \mathbb{I}[i > 1] \times \log C[v = y_i] \mathbb{I}[i = 1], \quad \text{где:}
#     $$
#
#     $$A_{vu} = \frac{\sum_{y}\sum_{i=2}^{|y|} \mathbb{I}[y_{i} = v, y_{i - 1} = u]}{\sum_{y}\sum_{i=2}^{|y|} \mathbb{I}[y_{i-1} = u]}
#     $$
#     $$
#     C_v = \frac{\sum_{y}\mathbb{I}[y_{1} = v]}{\sum_{y}1}
#     $$
#
# 2. Реализовать процедуру получения оптимальной выходной последовательности, используя алгоритм Витерби
#
# 3. Подобрать на валидационной выборке веса модели $w_1$ и $w_2$
#
# Для исходной модели, дающей на валидационной и тестовой выборке F1 меру 0.408 и 0.46 соответственно, качество после такого пост-процессинга выросло до 0.461 и 0.493. Заметим, что для тестирования модели не нужно переобучать исходную модель. Для более устойчивого поведения модели, используйте сглаживание матрицы $A$ (добавьте перед нормировкой ко всем значениям одинаковое небольшое число).
#
# **<font color='red'>Задание. Реализуйте требуемую модель, добейтесь улучшения качества на валидации и тесте, сделайте выводы.</font>**

# %%
class ViterbiPostprocesser:    
    def __init__(self, model, smoothing=1.0, w=1.0):
        """
        model : torch.nn.Module
            Tagging model
        smoothing : float, constant in add-k-smoothing
        w : feature weight
             Use w for first feature weight and (1 - w) for second feature.
        """
        self.model = model
        self.smoothing = smoothing
        self.w = w
        
    def fit(self, dataset):
        """
        Fit the model using maximum likelihood method.
        
        dataset: torch.dataset
            One element if pair (sentence, tags) 
        """
        ######################################
        ######### YOUR CODE HERE #############
        ######################################        
        
    def decode(self, model_logprobs):
        """
        Viterbi decoding for input model output
        
        model_logprobs : torch.tensor
            Shape is (sequence_length, tag_space_size) 
        """
        ######################################
        ######### YOUR CODE HERE #############
        ######################################        
    
    def predict_for_batch(self, x_batch):
        """
        Returns predictions for x_batch. Use viterbi decoding.
        
        return type: torch.LongTensor
        return shape: (number of samples in batch, number words in sentence.
        
        ----------
        Parameters
        x_batch: torch.LongTensor with shape (number of samples in batch, number words in sentence).
        """
        ######################################
        ######### YOUR CODE HERE #############
        ######################################

# %% [markdown]
# Место для ваших экспериментов:

# %%
    ######################################
    ######### YOUR CODE HERE #############
    ######################################

# %% [markdown]
# ## Бонусная часть. Обучаемый постпроцессинг через CRF (3 балла).
#
# Реализуйте сами / модифицируйте открытую реализацию CRF, соответствующую реализации обучаемого пост-процессинга в лекции. Например, можно использовать эту реализацию:
# https://pytorch.org/tutorials/beginner/nlp/advanced_tutorial.html
#
# В такой модели должно использоваться два типа признаков:
#
# * $|Y|\times|Y|$ признаков, учитывающих выход модели:
# $$	\phi_{uv}(y_{i-1}, y_i, x_i) = \mathbb{I}[y_{i-1} = u]\mathbb{I}[y_i = v] S_{i,y_i}$$
# * $|Y|\times|Y|$ признаков, учитывающих связь меток:
# $$ \psi_{uv}(y_{i-1}, y_i) = \mathbb{I}[y_{i-1} = u]\mathbb{I}[y_i = v] $$
#
# Итоговое выражение для $G_{x, i}[y_{i-1}, y_i]$ выглядит так:
# $$
# G_{x, i}[y_{i-1}, y_i] = w(y_{i-1}, y_i) S_{i, y_i} + a(y_{i-1}, y_i)
# $$
#
#
# **<font color='red'>Задание. Обучите модель BiLSTM-CRF в едином пайплайне, добейтесь улучшения качества модели, сделайте выводы по проделанным экспериментам.</font>**

# %%
######################################
######### YOUR CODE HERE #############
######################################

# %% [markdown]
# ## Бонусная часть. Дополнительный char-LSTM слой (2 балла).
#
# Добавьте к слою представлений слов обучаемые char-based представления. Каждое слово разделяется на символы и прогоняется через char-based сеть (например, через LSTM). Финальное состояние сети (или конкатенация двух финальных состояний в случае bidirectional LSTM) подаётся как дополнительное представление.
#
# **<font color='red'> Задание. Обучите модель с дополнительным представлением и сравните качество с исходной моделью. Сделайте выводы по проделанным экспериментам.</font>**

# %%
######################################
######### YOUR CODE HERE #############
######################################
